# %%
from tokopaedi import search, get_product
import pandas as pd
import time, random, uuid, os, json
from typing import Any, Dict, List, Optional

# %%
KEYWORDS = [
    "elektronik", "handphone", "komputer", "fashion pria", "fashion wanita",
    "ibu dan bayi", "kecantikan", "kesehatan", "rumah tangga", "olahraga",
    "hobi", "makanan", "minuman", "sekolah",
]

MAX_PER_KEYWORD = 500
SLEEP_SEARCH = (3.0, 5.0)
SLEEP_DETAIL = (1.2, 2.0)
RETRY_PER_ITEM = 2

CSV_PATH = "tokopedia_500.csv"
PARQUET_PATH = "tokopedia_500.parquet"  # ditulis kalau pyarrow ada
STATE_PATH = "tokopedia_state.json"     # menyimpan keyword yang sudah selesai

# %%
# ---------- Util State & IO ----------

def load_state() -> Dict[str, Any]:
    if os.path.exists(STATE_PATH):
        try:
            with open(STATE_PATH, "r", encoding="utf-8") as f:
                return json.load(f)
        except Exception:
            pass
    return {"completed_keywords": []}

def save_state(state: Dict[str, Any]):
    tmp = STATE_PATH + ".tmp"
    with open(tmp, "w", encoding="utf-8") as f:
        json.dump(state, f, ensure_ascii=False, indent=2)
    os.replace(tmp, STATE_PATH)

def load_existing_rows() -> pd.DataFrame:
    """Load CSV/Parquet kalau ada (prioritas CSV)."""
    if os.path.exists(CSV_PATH):
        try:
            return pd.read_csv(CSV_PATH)
        except Exception:
            pass
    if os.path.exists(PARQUET_PATH):
        try:
            return pd.read_parquet(PARQUET_PATH)
        except Exception:
            pass
    return pd.DataFrame(columns=[
        "product_id","product_name","url","description","price",
        "sold_count","rating","total_stock","category","keyword"
    ])

def write_checkpoint(df: pd.DataFrame):
    # tulis CSV
    tmp = CSV_PATH + ".tmp"
    df.to_csv(tmp, index=False, encoding="utf-8-sig")
    os.replace(tmp, CSV_PATH)

    # tulis Parquet kalau tersedia
    try:
        import pyarrow  # noqa: F401
        tmp_pq = PARQUET_PATH + ".tmp"
        df.to_parquet(tmp_pq, index=False)
        os.replace(tmp_pq, PARQUET_PATH)
    except Exception:
        # abaikan kalau pyarrow tidak ada
        pass

# ---------- Helpers scraping ----------

def extract_description(detail) -> str:
    data = None
    if hasattr(detail, "json"):
        try:
            data = detail.json()
        except Exception:
            data = None
    if data is None and isinstance(detail, dict):
        data = detail

    if isinstance(data, dict):
        pdp = data.get("product_detail") or {}
        if isinstance(pdp, dict) and pdp.get("description"):
            return str(pdp["description"]).strip()
        d = data.get("description") or data.get("long_description") or ""
        return str(d).strip()

    desc = getattr(detail, "description", "") or ""
    if not desc:
        pdp = getattr(detail, "product_detail", None)
        if isinstance(pdp, dict) and pdp.get("description"):
            desc = pdp["description"]
    return str(desc).strip()

def to_dict(detail) -> Dict[str, Any]:
    if hasattr(detail, "json"):
        try:
            return detail.json()
        except Exception:
            pass
    if isinstance(detail, dict):
        return detail
    # fallback objek attribute ke dict minimal
    return {
        "sold_count": getattr(detail, "sold_count", None),
        "total_stock": getattr(detail, "total_stock", None),
        "category": getattr(detail, "category", None),
    }

def get_detail_safe(pid):
    last_err = None
    for attempt in range(RETRY_PER_ITEM + 1):
        try:
            return get_product(product_id=pid, debug=False)
        except Exception as e:
            last_err = e
            if attempt < RETRY_PER_ITEM:
                time.sleep((1.2 * (2 ** attempt)) + random.uniform(0, 0.5))
            else:
                raise last_err

def safe_pid(pid, name, url):
    if pid:
        return pid
    base = url or name or str(uuid.uuid4())
    return f"noid::{abs(hash(base))}"

# %%
# ---------- Main ----------

def main():
    # Load state + data existing (resume)
    state = load_state()
    completed = set(state.get("completed_keywords", []))

    df_existing = load_existing_rows()
    if "product_id" not in df_existing.columns:
        df_existing["product_id"] = []
    # set untuk skip id yang sudah ada
    seen_ids = set(df_existing["product_id"].astype(str).tolist())

    # working buffer (biar tidak bolak-balik read/write besar)
    rows_buffer: List[Dict[str, Any]] = []

    for kw in KEYWORDS:
        if kw in completed:
            print(f"✓ Skip '{kw}' (sudah selesai sebelumnya)")
            continue

        print(f"\n=== Keyword: {kw} (max {MAX_PER_KEYWORD}) ===")
        # SEARCH: guard NoneType (memperbaiki error Non-iterable)
        try:
            results = search(kw, max_result=MAX_PER_KEYWORD, debug=False)
        except Exception as e:
            print(f"search gagal untuk '{kw}': {e}")
            time.sleep(random.uniform(*SLEEP_SEARCH))
            continue

        # pastikan iterable -> list, handle None
        try:
            results = list(results or [])
        except TypeError:
            results = []

        if not results:
            print(f"search untuk '{kw}' tidak mengembalikan hasil, skip.")
            time.sleep(random.uniform(*SLEEP_SEARCH))
            # tandai keyword “selesai” meski kosong, agar tidak diulang-ulang
            completed.add(kw)
            state["completed_keywords"] = sorted(list(completed))
            save_state(state)
            continue

        n = len(results)
        print(f"Ditemukan {n} produk untuk '{kw}'")
        time.sleep(random.uniform(*SLEEP_SEARCH))

        for i, prod in enumerate(results, 1):
            pid   = getattr(prod, "product_id", None)
            name  = getattr(prod, "product_name", "") or ""
            url   = getattr(prod, "url", None)
            price = getattr(prod, "price", None)
            rating= getattr(prod, "rating", None)
            category = getattr(prod, "category", None)

            # stabilkan id + skip jika sudah ada
            pid = str(safe_pid(pid, name, url))
            if pid in seen_ids:
                if i % 50 == 0:
                    print(f"[{kw} {i}/{n}] (skip dup) {name[:60]}")
                continue

            desc = None
            sold_count = None
            total_stock = None

            try:
                det = get_detail_safe(pid)
                desc = extract_description(det)
                data = to_dict(det)
                sold_count  = data.get("sold_count")
                total_stock = data.get("total_stock")
                category    = data.get("category") or category
            except Exception as e:
                print(f"[{kw} {i}/{n}] detail gagal ({e}) — simpan meta search saja.")

            row = {
                "product_id": pid,
                "product_name": name,
                "url": url,
                "description": desc,
                "price": price,
                "sold_count": sold_count,
                "rating": rating,
                "total_stock": total_stock,
                "category": category,
                "keyword": kw,
            }
            rows_buffer.append(row)
            seen_ids.add(pid)

            # progress log ringan
            print(f"[{kw} {i}/{n}] {name[:60]}")
            time.sleep(random.uniform(*SLEEP_DETAIL))

            # checkpoint per 100 item baru (hemat I/O)
            if len(rows_buffer) >= 100:
                df_add = pd.DataFrame(rows_buffer)
                rows_buffer.clear()
                df_existing = pd.concat([df_existing, df_add], ignore_index=True)
                # dedup + write
                df_existing = df_existing.drop_duplicates(subset=["product_id"]).reset_index(drop=True)
                write_checkpoint(df_existing)
                print(f"↳ checkpoint ({len(df_existing)} rows)")

        # selesai satu keyword → tulis checkpoint & update state
        if rows_buffer:
            df_add = pd.DataFrame(rows_buffer)
            rows_buffer.clear()
            df_existing = pd.concat([df_existing, df_add], ignore_index=True)
            df_existing = df_existing.drop_duplicates(subset=["product_id"]).reset_index(drop=True)
            write_checkpoint(df_existing)

        completed.add(kw)
        state["completed_keywords"] = sorted(list(completed))
        save_state(state)
        print(f"↳ selesai '{kw}' — total rows: {len(df_existing)}")

    # final save (idempotent)
    df_existing = df_existing.drop_duplicates(subset=["product_id"]).reset_index(drop=True)
    write_checkpoint(df_existing)
    print(f"\n✅ Done. Saved {len(df_existing)} rows → {CSV_PATH} (+parquet jika tersedia)")

# %%
if __name__ == "__main__":
    main()
# Out:
# === Keyword: elektronik (max 500) ===
# Ditemukan 258 produk untuk 'elektronik'
# [elektronik 1/258] ENOVE - Device Stylish 3 Warna | Bisa Dijeda | Compact & Ele
# [elektronik 2/258] LIGE sub-merek FOXBOX Jam Tangan Pria Fashion Baru Jam Tanga
# [elektronik 3/258] HEPU HP-985 Power Bank 30.000 Mah  1 to 6
# [elektronik 4/258] PESANAN KHUSUS CV. SYAILENDRA ELEKTRONIK
# [elektronik 5/258] Timbangan elektronik presisi tinggi timbangan elektronik por
# [elektronik 6/258] [EXCLUSIVE DADAHAPHONE] MIXIO MP-08 5000mAh Powerbank Mini 2
# [elektronik 7/258] LED TV POLYTRON 55" PLD 55UG9959 55 INCH USB MOVIE ANDROID N
# [elektronik 8/258] IFM ELECTRONIC PN7094 75 BAR
# [elektronik 9/258] SS 12 IN 1 Electric Stationery Set / Set Alat Tulis Elektron
# [elektronik 10/258] Komputer All in One Baru, Intel Core i7 Gen ke-6, RAM 16GB +
# [elektronik 11/258] 【Ready+Bisa COD】Advance Speaker Bluetooth Karaoke TWS 8inch+
# [elektronik 12/258] 【Promo Live】HSA Electric Saver GEN 3 | Alat Penghemat Daya L
# [elektronik 13/258] VIVAN VS12 Speaker Bluetooth  Portable Super Bass IPX6 TWS B
# [elektronik 14/258] VIVAN Life P1 2in1 TWS & Mini Powerbank 2000mAh Power Bass E
# [elektronik 15/258] Sankeshu Power Bank 20000mAh, PD22.5W, Layar LED, Dual Port
# [elektronik 16/258] SOARFLY 60000mAh 22.5W Outdoor Power Pengisian Cepat Luar Ru
# [elektronik 17/258] [ New arrival ] Smartphone Hitam S25 Plus Android 7.5 Inci L
# [elektronik 18/258] SANEX Oven Listrik Royal Mastery Series 30 Liter SO-4304
# [elektronik 19/258] Lampu LED Ufo HighBay Philips BY229P LED195 220-240V Putih 6
# [elektronik 20/258] kidditoy Mainan Piano Anak Elektronik 37 Keys Digital Elektr
# [elektronik 21/258] [ MANSION X Mas Bois ] Apple iPhone 16 Plus 128GB & 256GB Ga
# [elektronik 22/258] Timbangan Dapur Akurat Gram Kecil Timbangan Elektronik
# [elektronik 23/258] Kunci Kabinet Elektronik / Kunci Sidik Jari Elektrik F040
# [elektronik 24/258] [ Ponsel asli + COD ] Smartphone Hitam S24 Plus Android 7.5
# [handphone 116/279] INFINIX Smart 9 HD RAM 4GB 64GB Garansi Resmi Indonesia
# [handphone 117/279] Infinix Note 50X 5G+ 8/256GB - Up to 16GB Extended RAM - Dim
# [handphone 118/279] Xiaomi Redmi Note 14 5G 8/128GB 8/256GB 12/512GB Garnasi Res
# [handphone 119/279] Realme C71 ( 4/128 6/128 8/128 ) Garansi Resmi Realme
# [handphone 120/279] Xiaomi Redmi Note 14 8/128GB 8/256GB - Garansi resmi
# [handphone 121/279] Xiaomi Redmi 10A 3/64GB - Sky Blue
# [handphone 122/279] [Spesial Robi Bois] Realme Note 60 [4GB+64GB] [6GB+128GB] Ga
# [handphone 123/279] Xiaomi Redmi Note 14 8/128 8/256 8/128GB 8/256GB 8GB 128GB 2
# [handphone 124/279] Handphone A60 8/256 gb Garansi Resmi
# [handphone 125/279] 【Exclusive Baim Wong】MiotMeta realme Note 60 6GB+12GB*|128GB
# [handphone 126/279] 【 msub0702 Exclusive】MiotMeta realme Note 60 4GB+8GB*|64GB (
# Traceback (most recent call last):
#   File "c:\Users\Aufii\AppData\Local\Programs\Python\Python312\Lib\site-packages\tokopaedi\get_product.py", line 186, in get_product
#     product_data = product_details_extractor(result_json)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Aufii\AppData\Local\Programs\Python\Python312\Lib\site-packages\tokopaedi\get_product.py", line 13, in product_details_extractor
#     components = pdp.get("components", [])
#                  ^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'get'
#
# Traceback (most recent call last):
#   File "c:\Users\Aufii\AppData\Local\Programs\Python\Python312\Lib\site-packages\tokopaedi\get_product.py", line 186, in get_product
#     product_data = product_details_extractor(result_json)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Aufii\AppData\Local\Programs\Python\Python312\Lib\site-packages\tokopaedi\get_product.py", line 13, in product_details_extractor
#     components = pdp.get("components", [])
#                  ^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'get'
#
# Traceback (most recent call last):
#   File "c:\Users\Aufii\AppData\Local\Programs\Python\Python312\Lib\site-packages\tokopaedi\get_product.py", line 186, in get_product
#     product_data = product_details_extractor(result_json)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Aufii\AppData\Local\Programs\Python\Python312\Lib\site-packages\tokopaedi\get_product.py", line 13, in product_details_extractor
#     components = pdp.get("components", [])
#                  ^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'get'
#
# [handphone 127/279] detail gagal (name 'exit' is not defined) — simpan meta search saja.
# [handphone 127/279] 【andriyadiishow EXCLUSIVE】Official realme C71 4GB+8GB* |128G
# [handphone 128/279] realme C75 8GB+16GB*|128 GB | IP66/68/69 Dust & Water Resist
# [handphone 129/279] MiotMeta  realme C61 8+128 (50MP AI Camera | 90Hz Eye Comfor
# [handphone 130/279] 【andriyadiishow EXCLUSIVE】MiotMeta  realme C71 4GB+8GB* |128
# [handphone 131/279] 【Gadgetasik EXCLUSIVE】realme Note 60x 4GB+8GB*|64GB Rangka M
# [handphone 132/279] 【kepogejet.id EXCLUSIVE】MiotMeta realme Note 60x 4GB+8GB*|64
# [handphone 133/279] HP Smartphone Y17 8/256 GB New Harga Murah Dual SIM  Bergara
# [handphone 134/279] Xiaomi Redmi 14C 6/128GB | 8/256GB 6.88 Inch Garansi Resmi
# [handphone 135/279] 【Kepogejet.id EXCLUSIVE】MiotMeta  realme C75x 8GB+16GB*|128G
# [handphone 270/279] [ Champion X Sewa ] APPLE IPHONE 11 GARANSI INTERNATIONAL |
# [handphone 272/279] Samsung A35 5G Segel Indonesia
# [handphone 273/279] hp note 9
# [handphone 274/279] sony xperia xz2 compact docomo 4G LTE handphone murah termur
# [handphone 275/279] Handphone Nokiaa Flip 2720 Hp Nokia 2720 Lipat Kamera
# [handphone 276/279] HP vivo Y55 2/16gb second original
# [handphone 277/279] hp bekas rusak berbagai varian
# [handphone 278/279] (GSM) HP / HANDPHONE Motoralo StarTAC
# [handphone 279/279] CUCI GUDANG Handphone Android Gambling Second Minusan Bahan
# ↳ selesai 'handphone' — total rows: 534
#
# === Keyword: komputer (max 500) ===
# Ditemukan 295 produk untuk 'komputer'
# [komputer 1/295] Pc Gaming core i7 Full set Ram 16 Gb Vga 4 Gb Monitor 24 cur
# [komputer 2/295] Set PC Komputer Intel Core i5-12400 Gen-12 RAM 8GB SSD || Fr
# [komputer 3/295] ASUS PC Desktop P500MV Intel Core i3 1315 RAM 8 GB SSD 512 G
# [komputer 4/295] CPU Rakitan Intel Core i5 3470 Up 3.6Ghz PC Komputer Gaming
# [komputer 6/295] Set PC Slim Intel Core i5-14400 Gen-14 RAM 8GB SSD || Framel
# [komputer 7/295] MSI MAG Infinite E1 [i5-14400 | 8GB DDR5 | 512GB | WIN 11 HO
# [komputer 8/295] PC all-in-one baru, prosesor Core i7/i5/i3, layar 22/24/27 i
# [komputer 9/295] Komputer PC all-in-one Komputer ultra-tipis Lenovo , kompute
# [komputer 10/295] MA Komputer Full Set ALL IN One PC intel I7 10750 RAM 16GB S
# [komputer 11/295] ASUS PC AIO A3402WVAK - Core I5 1335U 16GB 512GB 23.8" FHD W
# [komputer 12/295] Komputer Rakitan i5 3470 | Ram 8GB HDD 1TB SSD 120GB| Kantor
# [komputer 13/295] Asus PC Desktop P500MV - Intel core i3 1315 8GB 512GB W11 +
# [komputer 14/295] PC Rakitan Komputer Lengkap Siap Pakai Intel Core i3 RAM 8GB
# [komputer 15/295] PC Desktop DELL Optiplex 3090SFF i5-10505 16GB SSD512GB DVDR
# [komputer 16/295] PC/Komputer Rakitan i5 4570 8 GB SSD Murah Untuk Office Admi
# [komputer 17/295] PC All In One / PC AIO HP Pavilion 22 Core i5-6200 GeForce 9
# [komputer 18/295] MA Komputer Full PC All-in-One Baru Terbaru HD Super Tipis I
# [komputer 19/295] Lenovo A100 All In One PC Intel Intel N100 8GB 512SSD Window
# [komputer 20/295] PC Rakitan Gaming Fullset Intel Core i7 9700 RAM 32gb SSD 51
# [komputer 21/295] Lenovo IdeaCentre AIO 24ARR9 Ryzen 3 7335U 8GB 512GB W11 OHS
# [komputer 22/295] Laptop HP Athlon Silver 7120U Radeon 8GB RAM 512GB SSD Silve
# [komputer 23/295] Lenovo IdeaCentre AIO 3 22IAP7 Core i5-12450H 8GB 512GB SSD
# [komputer 24/295] AIO ASUS A3202WBAK BPB1820W Celeron 7305 8GB 256GB W11 Home
# [komputer 25/295] PC Rakitan Core i5 Lengkap ( Siap Pakai Kantor / Office / ad
# [komputer 26/295] JUTU Komputer PC all in one full set baru Core Intel i5/i7 U
# [komputer 27/295] PC RAKITAN + MONITOR | RAM 16GB | PC FULLSET i5 I7 | KOMPUTE
# [komputer 28/295] Advan All In One PC AIO OnePC Intel N100 ram 4GB ssd 128GB W
# [komputer 29/295] ASUS PC ALL IN ONE A3202WBAK i3-1215U 8GB 512G Intel UHD 21,
# [komputer 30/295] ADVAN OnePC All-in-One PC AIO Intel N100 4GB/128GB 24" inch
# [komputer 31/295] LAPTOP HP 14 I7 PAK HENDRY
# [komputer 32/295] Asus Pc Desktop S500TE 385000002W I3 13100 8GB 512GB Win11 2
# [komputer 33/295] Soflogic All In One PC Z2One 24 Inch i5-3470/16G+512G
# [komputer 34/295] PC/KOMPUTER RAKITAN KANTOR i5 12400 RAM 16GB FULLSET / CPU/P
# [komputer 35/295] Komputer PC all-in-one Intel Core i3 Gen ke-8, RAM 16GB SSD
# [komputer 36/295] Intel i5 12450H PC gaming full set ,mini komputer desktop co
# [komputer 37/295] PC Rakitan Core i5 RAM 32GB 16GB 8GB DDR4SSD 256GB Baru Gara
# [komputer 38/295] HW [layar sentuh]Komputer All in one PC gaming Core Intel i5
# [komputer 39/295] eFound Komputer All-in-One PC Baru Core i3/i5/i7, RAM 8GB/16
# [komputer 40/295] PC/KOMPUTER KANTOR i5 6500 RAM 16GB MB ASUS/GA FULLSET
# [komputer 41/295] 1 Set  PC Komputer Rakitan Lengkap Monitor 19 inch Garansi 1
# [komputer 42/295] Komputer All-in-One Baru Core i3/i5/i7 RAM 8GB/16GB SSD 256G
# [komputer 43/295] Paket Komputer Fullset Kasir Minimarket Sekolah Kantor Core
# [komputer 44/295] Oases Komputer All in one 8GB RAM 256GB SSD Terbaru FHD Supe
# [komputer 45/295] GAMERS GEAR COMPUTER | INTEL I3 - 4160 | RX 580 8GB | 8GB |
# [komputer 46/295] PC Rakitan Kantor Core i5 SSD 256GB Monitor Lengkap Bergaran
# [komputer 47/295] PC Gaming 12th Gen | i3-12100F | GTX 1650 | 16GB | NVME | Re
# [komputer 48/295] RAKITAN PC GAMING FULL SET INTEL CORE I7 RAM 8GB SSD 128GB +
# [komputer 49/295] Paket Komputer/Pc Kasir Intel Core I3 2120|4GB|HDD 500GB
# [komputer 50/295] MA touchscreen Laptop Baru 15.6 Inci untuk Gaming dan Kantor
# [komputer 51/295] KOMPUTER PC CPU RAKITAN Intel Core i5 3,2Ghz Baru Garansi 1
# [komputer 52/295] PC GAMING FULL SET CORE I3 GEN 6 DELL RAM 8 GB SSD 256 GB MO
# [komputer 53/295] PC Gaming Editing | AMD Rysen 5 4600G | RAM 16GB 32 GB | SSD
# [komputer 54/295] Komputer Rakitan Intel i5 12400F + VGA AMD NVIDIA Rakitan i5
# [komputer 55/295] HW Komputer Full PC All-in-One Baru Terbaru HD Super Tipis I
# [komputer 56/295] PC Rakitan Fullset Murah Intel Core i5 3470 Ram 16gb SSD 256
# [komputer 57/295] PC GAMING CORE I5 12400F RAM 32 GB SSD 512 GB RTX 3050 SIAP
# [komputer 58/295] PS- PC murah intel core i5 4570 ssd 240 ram 16Gb
# [komputer 59/295] Soflogic All In One PC Z2One 19 Inch i5-3470/8G+256G
# [komputer 60/295] Paket komputer lenovo i5 6500 LED 20 Inci m910s generasi 6 V
# [komputer 61/295] PC RAKITAN/KOMPUTER KANTOR COREI5 3470 SIAP PAKAI CUMA 2 JTA
# [komputer 62/295] Komputer Rakitan Intel i3 3240 / i5 3470 Pc Business/Home/Of
# [komputer 63/295] Paket PC Kantoran Core i5 8GB with LED 19 + Logitech MK120
# [komputer 64/295] PC/CPU KANTOR/SEKOLAH i5 8400/8500 RAM 16GB FULLSET
# [komputer 65/295] Cpu Rakitan Fullset Core i5 Ram 16 Gb Ssd 256 Gb Monitor 19
# [komputer 66/295] PC Rakitan Core i5 + Monitor 19" / RAM 8 GB / SSD / PC ADMIN
# [komputer 67/295] HP 14 EP0269TU Intel Core i3 1315 RAM 8GB 512GB SSD FHD
# [komputer 68/295] paket fullset Cpu HP core i5-gen4/8gb/500gb/ LED 19"inch + k
# [komputer 69/295] Pc Rakitan/core i5/Ram 8gb/Ssd 120gb Monitor 19 in full set
# [komputer 70/295] LENOVO PC DESKTOP IC 3 07IAB7 - 7DID CORE I3 4GB 256GB 21.5"
# [komputer 71/295] PAKET LENGKAP PC BRANDED KOMPUTER KANTOR Intel Core I5 LED 1
# [komputer 72/295] 1SET KOMPUTER BUILD UP PC LENOVO CORE I5 8GB 500GB LED ACER
# [komputer 73/295] PC All In One / PC AIO Lenovo C460 Core i5-4570 GeForce 800M
# [komputer 74/295] PC Rakitan Gaming Full Set Intel Core i5 2400 BLAZE | RAM 8G
# [komputer 75/295] PC Rakitan Gaming Core i7 / Ryzen 7 / RAM 16GB SSD / GTX 750
# [komputer 76/295] PC Gaming i5 12400 RTX 3050 Dual Fan 6GB RAM 16GB DDR4 SSD 2
# ...
# [sekolah 98/309] Tas Ransel Sekolah Anak Perempuan SD SMP SMA Wanita Premium
# [sekolah 99/309] AKSESORIS SEKOLAH SMP DAN SMA
# [sekolah 100/309] Celana Sekolah Panjang SMP, SMA Coklat Merek Seragam
# ↳ checkpoint (3763 rows)
# [sekolah 101/309] CONVERSE Backpack Classic Go 2 Korean Style / Ransel Ala Kor
# [sekolah 102/309] Celana Sekolah Panjang Karet Hitam SD, SMP Jumbo Merek Bullo
# [sekolah 103/309] tas sekolah anak perempuan 5in 1 tas ransel anak tas bahu an
# [sekolah 104/309] Sepatu Sekolah NB Sol Putih Tinggi Sepatu Tali SD SMP SMA La
# [sekolah 105/309] Tas Ransel Sekolah untuk Cowo dan Cewek SD/SMP - Model Terba
# [sekolah 106/309] Tas Ransel Anak Laki Laki Dan Perempuan Fashion Kekinian Tas
# [sekolah 107/309] Tas sekolah anak perempuan sd smp sma polos tas ransel anak
# [sekolah 108/309] Tas Ransel Sekolah Terbaru Pria/Wanita SD, SMP, SMA/Tas Pung
# [sekolah 109/309] BUKU TULIS SIDU 32. 1 PAK/10 BUKU Kertas Sekolah Stationery
# [sekolah 110/309] Tas Ransel Sekolah Anak Perempuan SD SMP Banyak Ruang Dan Sa
