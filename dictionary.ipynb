# %%
from collections import Counter
import re, pandas as pd, json, os, pathlib
from collections import defaultdict

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

stopwords_id = set(stopwords.words('indonesian'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Aufii\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv('data/tokopedia_500.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3972 entries, 0 to 3971
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    3972 non-null   int64
#  1   product_name  3972 non-null   object
#  2   url           3972 non-null   object
#  3   description   3868 non-null   object
#  4   price         3972 non-null   int64
#  5   sold_count    3969 non-null   float64
#  6   rating        3380 non-null   float64
#  7   total_stock   3969 non-null   float64
#  8   category      3972 non-null   object
#  9   keyword       3972 non-null   object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 310.4+ KB

# %% [markdown]
# ## Most Common Words Data Scrape 1 (Product's Name, Description, adn Other Specification)

# %%
# --- kolom yang akan dianalisis ---
cols_to_check = ["product_name", "description", 
                 "price", "sold_count", "rating", "total_stock", "category"]

def get_most_common_words(series, n=10):
    text = " ".join(series.dropna().astype(str))
    words = re.findall(r'\w+', text.lower())
    
    filtered = []
    for w in words:
        # skip angka murni
        if w.isdigit():
            continue
        # skip stopwords
        if w in stopwords_id:
            continue
        filtered.append(w)
    
    return Counter(filtered).most_common(n)

# --- loop tiap kolom ---
for col in cols_to_check:
    print(f"\n=== Most Common Words in '{col}' ===")
    common_words = get_most_common_words(df[col], n=10)
    for word, count in common_words:
        print(f"{word}: {count}")
# Out:
# === Most Common Words in 'product_name' ===
# wanita: 591
# pria: 502
# bayi: 438
# anak: 399
# sekolah: 376
# set: 371
# tas: 346
# paket: 331
# celana: 325
# alat: 323
#
# === Most Common Words in 'description' ===
# produk: 4491
# cm: 4035
# bahan: 3003
# x: 2910
# ukuran: 2555
# warna: 1974
# kulit: 1964
# barang: 1768
# cocok: 1735
# size: 1659
#
# === Most Common Words in 'price' ===
#
# === Most Common Words in 'sold_count' ===
#
# === Most Common Words in 'rating' ===
#
# === Most Common Words in 'total_stock' ===
#
# === Most Common Words in 'category' ===
# pria: 430
# wanita: 391
# android: 262
# os: 262
# celana: 213
# bayi: 185
# alat: 176
# kaos: 166
# tas: 166
# ransel: 148

# %%
# --- kumpulkan semua kata ---
all_words = []
for col in cols_to_check:
    common_words = get_most_common_words(df[col], n=None)  # ambil semua kata
    all_words.extend(common_words)

# --- gabungkan count dari semua kolom ---
total_counter = Counter()
for word, count in all_words:
    total_counter[word] += count

# --- ambil top 1000 ---
top_words = total_counter.most_common(1000)

# --- jadikan DataFrame ---
df_top_words1 = pd.DataFrame(top_words, columns=['word', 'count'])
df_top_words1.head
# Out:
# <bound method NDFrame.head of               word  count
# 0           produk   4518
# 1               cm   4049
# 2            bahan   3135
# 3                x   2949
# 4           ukuran   2591
# 5            kulit   2070
# 6            warna   2040
# 7            cocok   1778
# 8           barang   1776
# 9            paket   1756
# 10            bayi   1725
# 11            size   1702
# 12          celana   1556
# 13            anak   1517
# 14      pengiriman   1448
# 15         lingkar   1435
# 16          wanita   1377
# 17           mudah   1367
# 18         garansi   1334
# 19            pria   1258
# 20          nyaman   1242
# 21             tas   1171
# 22            alat   1148
# 23        membantu   1139
# 24          sesuai   1097
# 25            aman   1087
# 26             jam   1061
# 27            baju   1051
# 28             air   1045
# 29           wajah   1039
# 30           video   1011
# 31        memiliki   1003
# 32           berat   1000
# 33            toko    989
# 34             set    986
# 35             isi    969
# 36         premium    964
# 37              pc    955
# 38     spesifikasi    932
# 39               l    913
# 40        pinggang    850
# 41               m    825
# 42         sekolah    819
# 43           tahan    819
# 44             ram    815
# 45         pilihan    814
# 46          desain    803
# 47           harga    803
# 48         minuman    792
# 49              to    790
# 50        tersedia    787
# 51        olahraga    779
# 52           lebar    778
# 53          lembut    774
# 54            kaos    766
# 55           hitam    756
# 56          lengan    754
# 57              kg    750
# 58              in    738
# 59            anti    733
# 60             pcs    728
# 61            dada    726
# 62          varian    718
# 63     berkualitas    714
# 64           tubuh    698
# 65        kualitas    692
# 66        unboxing    676
# 67            kaki    670
# 68              xl    670
# 69            core    666
# 70            free    663
# 71         kemasan    657
# 72             usb    656
# 73           model    647
# 74               a    639
# 75        original    632
# 76         pesanan    631
# 77          detail    628
# 78             and    623
# 79            daya    621
# 80           order    613
# 81       kesehatan    612
# 82           mohon    603
# 83           ready    602
# 84         dipakai    599
# 85           pakai    598
# 86              no    592
# 87         dikirim    589
# 88              ya    587
# 89         terbuat    580
# 90           cream    578
# 91             rak    571
# 92        langsung    571
# 93            chat    569
# 94           intel    567
# 95          kemeja    565
# 96           cepat    565
# 97         makanan    564
# 98            foto    562
# 99              bb    560
# 100         tangan    549
# 101           baby    545
# 102          fitur    545
# 103          badan    540
# 104       material    537
# 105         proses    537
# 106     dilengkapi    534
# 107          botol    528
# 108          tebal    522
# 109          halus    517
# 110         ransel    516
# 111            ssd    515
# 112            8gb    514
# 113          layar    514
# 114             up    513
# 115              c    513
# 116           note    511
# 117          kirim    506
# 118        menjaga    505
# 119        packing    504
# 120           bpom    503
# 121            the    501
# 122             ld    498
# 123        baterai    495
# 124         pendek    494
# 125         ringan    484
# 126         sehari    482
# 127            box    472
# 128              s    472
# 129        android    469
# 130        lengkap    466
# 131       komputer    456
# 132          rumah    455
# 133          resmi    455
# 134          putih    451
# 135     penggunaan    450
# 136           with    445
# 137      indonesia    443
# 138            all    436
# 139         terima    436
# 140        selamat    434
# 141           type    433
# 142      deskripsi    433
# 143          harap    431
# 144           tali    430
# 145      kebutuhan    430
# 146         kering    429
# 147           kuat    424
# 148        terbaik    419
# 149             1x    416
# 150          pijat    413
# 151        vitamin    412
# 152          pilih    412
# 153         bubble    411
# 154       maksimal    408
# 155          wajib    407
# 156             ml    406
# 157        pakaian    405
# 158          jenis    405
# 159           stok    403
# 160        berbeda    401
# 161       silahkan    401
# 162      perawatan    400
# 163          motif    399
# 164            for    397
# 165            fit    394
# 166         khusus    392
# 167             os    392
# 168          pedas    389
# 169            xxl    387
# 170           dual    386
# 171            dll    384
# 172           buah    383
# 173        praktis    383
# 174        membeli    383
# 175            sim    382
# 176        setelan    380
# 177          admin    379
# 178             yg    374
# 179       menerima    374
# 180          power    373
# 181             i5    372
# 182    penyimpanan    372
# 183        plastik    372
# 184         gaming    370
# 185      kapasitas    370
# 186           asli    368
# 187          alami    367
# 188   meningkatkan    367
# 189        catatan    366
# 190           unit    364
# 191          happy    363
# 192        monitor    358
# 193          katun    356
# 194          panas    355
# 195         gambar    355
# 196      pembelian    355
# 197      bluetooth    354
# 198     kenyamanan    354
# 199          256gb    350
# 200           paha    350
# 201            led    349
# 202          mesin    349
# 203         sepatu    347
# 204             sd    346
# 205        rakitan    346
# 206        manfaat    346
# 207          makan    344
# 208         minyak    342
# 209          serum    338
# 210       komplain    338
# 211         kamera    336
# 212            one    335
# 213       keyboard    334
# 214      kerusakan    334
# 215          merah    332
# 216           cuci    330
# 217           gram    330
# 218           kayu    330
# 219          karet    329
# 220            new    328
# 221        variasi    328
# 222       tambahan    328
# 223        fashion    326
# 224          bubuk    326
# 225          murah    323
# 226           kain    323
# 227          rusak    323
# 228          dress    321
# 229           buku    321
# 230           otot    320
# 231          mouse    320
# 232     mengurangi    320
# 233            cod    318
# 234        speaker    318
# 235          kabel    317
# 236           laki    315
# 237           full    312
# 238         fungsi    312
# 239          polos    311
# 240          stock    311
# 241             gb    309
# 242          128gb    308
# 243        display    307
# 244         camera    307
# 245              p    307
# 246     mengandung    305
# 247        kondisi    305
# 248         atasan    300
# 249        terbaru    300
# 250       diterima    300
# 251           16gb    294
# 252       shopping    294
# 253          halal    293
# 254      pemakaian    293
# 255          kasih    291
# 256           suhu    290
# 257    mencerahkan    289
# 258          hemat    289
# 259           mata    289
# 260          ruang    289
# 261             mm    289
# 262           wrap    288
# 263            nya    288
# 264          utama    287
# 265          darah    285
# 266          kotak    284
# 267          sehat    283
# 268             mp    282
# 269       tampilan    281
# 270          masuk    279
# 271            gym    278
# 272       pastikan    278
# 273       dapatkan    278
# 274     keunggulan    278
# 275           inch    276
# 276           adem    276
# 277             of    276
# 278           mini    275
# 279          super    274
# 280           mode    273
# 281         bersih    273
# 282          kerja    271
# 283            cek    271
# 284          orang    271
# 285            pro    270
# 286    multifungsi    269
# 287         terapi    269
# 288           rapi    268
# 289          black    267
# 290           wifi    267
# 291          malam    266
# 292         bentuk    266
# 293         sistem    266
# 294           skin    264
# 295      informasi    264
# 296         dewasa    263
# 297             hd    263
# 298          tidur    263
# 299           susu    263
# 300          dapur    262
# 301           saku    261
# 302        windows    260
# 303        listrik    259
# 304         office    259
# 305          bebas    257
# 306           gaya    257
# 307             hp    255
# 308        camilan    255
# 309          hasil    254
# 310           nama    254
# 311        hubungi    254
# 312           card    252
# 313          minum    249
# 314       sempurna    248
# 315          senin    247
# 316          tulis    244
# 317           body    244
# 318        keripik    243
# 319      kandungan    243
# 320         kapsul    242
# 321            gel    242
# 322        pembeli    241
# 323          susun    240
# 324          drink    240
# 325      aktivitas    239
# 326         casual    238
# 327            4gb    238
# 328     memudahkan    238
# 329            cpu    237
# 330         instan    236
# 331            oil    236
# 332   membersihkan    236
# 333          jaket    235
# 334        charger    235
# 335          audio    234
# 336        request    234
# 337        tekstur    233
# 338         minggu    233
# 339         santai    232
# 340            vga    232
# 341         gratis    231
# 342         elegan    231
# 343           tipe    230
# 344        jahitan    230
# 345         kantor    229
# 346        latihan    229
# 347        dijamin    227
# 348         tangga    226
# 349          kartu    226
# 350           efek    226
# 351            pas    226
# 352          water    225
# 353           usia    225
# 354            5cm    225
# 355             by    224
# 356           biru    224
# 357      kesalahan    224
# 358           food    222
# 359        jerawat    220
# 360        extract    219
# 361        nikmati    218
# 362             i7    217
# 363             si    217
# 364       produksi    217
# 365      serbaguna    216
# 366          sport    215
# 367           beli    215
# 368         casing    215
# 369     berbelanja    215
# 370            dus    213
# 371       skincare    212
# 372          white    212
# 373     resistance    211
# 374          bumbu    210
# 375          bonus    210
# 376        silakan    210
# 377          panci    209
# 378      processor    209
# 379        dimensi    209
# 380          sabtu    209
# 381         manual    208
# 382       diproses    208
# 383             lp    208
# 384          klaim    207
# 385      ketentuan    207
# 386      dirancang    207
# 387           gula    206
# 388         design    206
# 389            ghz    206
# 390         mainan    205
# 391         herbal    205
# 392       suplemen    205
# 393        battery    205
# 394           pink    204
# 395        standar    204
# 396          snack    203
# 397         dingin    203
# 398          menit    203
# 399           daun    202
# 400         kepala    202
# 401      handphone    201
# 402           high    201
# 403            non    201
# 404      mendukung    201
# 405      kecepatan    201
# 406      pemesanan    201
# 407             5g    200
# 408           acid    200
# 409          level    200
# 410              b    200
# 411           plus    198
# 412         cotton    198
# 413        tingkat    198
# 414          salah    198
# 415          manis    197
# 416         laptop    197
# 417            max    197
# 418        menarik    197
# 419       aplikasi    195
# 420          chart    195
# 421        layanan    194
# 422          suara    194
# 423         tampil    194
# 424          512gb    193
# 425           khas    192
# 426          kanan    192
# 427           face    191
# 428          leher    191
# 429          hijau    191
# 430          segar    191
# 431         random    191
# 432      toleransi    191
# 433          grade    190
# 434            kak    190
# 435      tambahkan    190
# 436             pj    190
# 437          store    189
# 438           kali    189
# 439            smp    188
# 440        digital    188
# 441           watt    188
# 442              d    188
# 443        stylish    188
# 444         tombol    188
# 445      stainless    187
# 446          mobil    187
# 447           band    187
# 448        quality    187
# 449    motherboard    187
# 450        cemilan    186
# 451      gendongan    186
# 452         modern    186
# 453      teknologi    186
# 454        samping    185
# 455       mencegah    185
# 456          ideal    185
# 457         dibawa    185
# 458      perempuan    184
# 459          lipat    184
# 460              f    184
# 461       menyerap    184
# 462       pengguna    184
# 463           slot    184
# 464           kiri    184
# 465          jeruk    183
# 466          ultra    183
# 467            rok    183
# 468             on    183
# 469        efektif    183
# 470           yoga    182
# 471             gr    182
# 472           muat    182
# 473            day    181
# 474         coklat    180
# 475       kekinian    179
# 476          melar    179
# 477        bintang    179
# 478          kurir    179
# 479         memory    179
# 480         powder    178
# 481        storage    178
# 482              g    178
# 483        fitness    177
# 484       otomatis    177
# 485           jual    177
# 486    disesuaikan    177
# 487         hadiah    176
# 488    niacinamide    175
# 489       keluarga    175
# 490         ongkir    175
# 491              t    174
# 492           ayam    174
# 493            mah    174
# 494          teman    174
# 495          tutup    173
# 496          beban    173
# 497          gurih    172
# 498           area    172
# 499        memilih    172
# 500          promo    171
# 501           wash    171
# 502        fullset    170
# 503        glowing    170
# 504            gen    170
# 505          jumbo    169
# 506         facial    169
# 507            teh    169
# 508          lampu    169
# 509           awet    169
# 510           klik    169
# 511            wib    169
# 512        ruangan    168
# 513            abu    168
# 514    kelengkapan    168
# 515         screen    167
# 516        product    167
# 517             i3    166
# 518        berlaku    166
# 519     disarankan    166
# 520         unisex    165
# 521            hdd    165
# 522          cerah    165
# 523          aktif    165
# 524      ekspedisi    165
# 525        running    164
# 526          mandi    164
# 527        mineral    164
# 528          toner    164
# 529          bantu    163
# 530      menyimpan    163
# 531      perbedaan    163
# 532    terimakasih    162
# 533        panduan    161
# 534       konsumsi    161
# 535           lupa    161
# 536           fast    160
# 537          sinar    160
# 538            sma    159
# 539      peralatan    159
# 540            1tb    159
# 541        instant    159
# 542          extra    159
# 543       tanggung    159
# 544       portable    158
# 545        kancing    158
# 546          kokoh    158
# 547              e    158
# 548           ddr3    158
# 549           blue    157
# 550            out    157
# 551          hadir    157
# 552       khawatir    157
# 553         solusi    156
# 554            yes    156
# 555          steel    155
# 556          angin    155
# 557        control    155
# 558         pasang    155
# 559          style    154
# 560     kecantikan    154
# 561         cahaya    154
# 562       keringat    154
# 563     pengalaman    154
# 564         bantal    153
# 565           case    153
# 566      pengisian    153
# 567           your    153
# 568             2x    153
# 569         formal    152
# 570         pensil    152
# 571     bergaransi    152
# 572          bibir    152
# 573           hati    152
# 574      pelanggan    152
# 575   perlengkapan    151
# 576          smart    151
# 577             my    151
# 578      tokopedia    151
# 579            psu    151
# 580        chipset    151
# 581           pagi    151
# 582         alamat    151
# 583       features    151
# 584        belanja    151
# 585       checkout    151
# 586     elektronik    150
# 587             4g    150
# 588         renyah    150
# 589           bahu    150
# 590           unik    150
# 591             pb    150
# 592      pembersih    149
# 593            mix    149
# 594        kantong    149
# 595     melindungi    149
# 596         length    149
# 597   pengembalian    149
# 598            tea    148
# 599           real    148
# 600            top    147
# 601       wireless    147
# 602           soft    147
# 603     tergantung    147
# 604    moisturizer    146
# 605       charging    146
# 606          ulang    146
# 607            via    146
# 608       keamanan    146
# 609          shirt    145
# 610            you    145
# 611         weight    145
# 612     terjangkau    145
# 613          pesan    145
# 614         series    144
# 615          kapas    144
# 616            pel    144
# 617          retur    144
# 618       official    143
# 619            lcd    143
# 620           pori    143
# 621             is    143
# 622           data    143
# 623          libur    143
# 624        elastis    142
# 625           game    142
# 626            5mm    142
# 627             mg    142
# 628        memasak    142
# 629         normal    142
# 630       elektrik    141
# 631         sachet    141
# 632         sendok    141
# 633        lengket    141
# 634          pecah    141
# 635          adobe    141
# 636            1kg    140
# 637           inci    140
# 638       diameter    140
# 639      kelebihan    140
# 640       customer    140
# 641         simpan    140
# 642         blouse    139
# 643        hampers    139
# 644              v    139
# 645             ai    139
# 646           buka    139
# 647          sakit    138
# 648          bekas    138
# 649          acara    138
# 650          rapih    138
# 651     dikonsumsi    138
# 652       backpack    137
# 653           home    136
# 654           ddr4    136
# 655          gelas    136
# 656       kekuatan    136
# 657         diatas    136
# 658        kendala    136
# 659       punggung    135
# 660        lapisan    135
# 661         hangat    135
# 662      komposisi    135
# 663         lemari    134
# 664        barrier    134
# 665         sablon    134
# 666        tertera    134
# 667            bag    133
# 668      keranjang    133
# 669          serat    133
# 670            abs    133
# 671     smartphone    132
# 672           midi    132
# 673         seller    132
# 674          lezat    132
# 675           noda    132
# 676             fi    132
# 677          30fps    132
# 678         ponsel    131
# 679          ganti    131
# 680          keren    130
# 681            fhd    130
# 682         piring    130
# 683          sikat    130
# 684      kombinasi    130
# 685         grosir    130
# 686             wi    130
# 687          bagus    130
# 688         merata    130
# 689          jeans    129
# 690           64gb    129
# 691          tipis    129
# 692            sel    129
# 693        tanggal    129
# 694         syarat    129
# 695        natural    128
# 696            ips    128
# 697          color    128
# 698         sensor    128
# 699           port    128
# 700      perangkat    128
# 701           70cm    128
# 702        legging    127
# 703      glad2glow    127
# 704           besi    127
# 705         kardus    127
# 706         ulasan    127
# 707           knit    126
# 708           lari    126
# 709            nfc    126
# 710    brightening    126
# 711          perut    126
# 712           hdmi    126
# 713         posisi    126
# 714       resolusi    126
# 715        service    126
# 716        outdoor    125
# 717        seragam    125
# 718          rayon    125
# 719          kelas    125
# 720        etalase    125
# 721        membaca    125
# 722         tulang    124
# 723          night    124
# 724       ceramide    124
# 725         rendah    124
# 726          pants    123
# 727           roda    123
# 728          sabun    123
# 729            fan    123
# 730          brand    123
# 731            com    123
# 732      meredakan    123
# 733            rgb    123
# 734       memenuhi    123
# 735           glow    122
# 736           busa    122
# 737              w    122
# 738         dicuci    122
# 739         memori    122
# 740       kegiatan    122
# 741         distro    121
# 742          korea    121
# 743            rom    121
# 744         lantai    121
# 745          sound    121
# 746         system    121
# 747           wide    121
# 748          modis    121
# 749          100cm    121
# 750     konfirmasi    121
# 751     pengukuran    121
# 752    ingredients    121
# 753         crispy    120
# 754          liter    120
# 755            dry    120
# 756      mengatasi    120
# 757          beras    119
# 758           krim    119
# 759          jalan    119
# 760    melembabkan    119
# 761          udara    119
# 762       terjamin    119
# 763       termurah    118
# 764            ori    118
# 765           enak    118
# 766      resleting    118
# 767          bikin    118
# 768           pola    118
# 769        kerupuk    117
# 770          nomor    117
# 771           best    116
# 772           lucu    116
# 773           debu    116
# 774             ac    116
# 775          cacat    116
# 776      berfungsi    116
# 777         kucing    115
# 778             uv    115
# 779       prosesor    115
# 780             it    115
# 781       pegangan    115
# 782        adaptor    115
# 783           50cm    115
# 784    berolahraga    115
# 785       collagen    114
# 786         makeup    114
# 787        samsung    114
# 788         double    114
# 789           3pcs    114
# 790       sensitif    114
# 791         harian    114
# 792           baca    114
# 793         banget    114
# 794         selera    114
# 795          bukti    114
# 796    dibersihkan    114
# 797          front    114
# 798          kerah    113
# 799           pack    113
# 800          500gb    113
# 801          wadah    113
# 802      sunscreen    113
# 803        desktop    113
# 804              n    113
# 805           nano    113
# 806        pinggul    113
# 807              h    113
# 808      perhatian    113
# 809       melayani    113
# 810          cargo    112
# 811          nyeri    112
# 812           sisi    112
# 813          1080p    112
# 814         dibuka    112
# 815         setuju    112
# 816          telon    111
# 817         cantik    111
# 818           asam    111
# 819         rambut    111
# 820        nutrisi    111
# 821     kesempatan    111
# 822         korean    110
# 823        formula    110
# 824       performa    110
# 825     pembayaran    110
# 826    menyegarkan    110
# 827    rekomendasi    110
# 828            lip    109
# 829          lokal    109
# 830        mencuci    109
# 831          label    109
# 832     keterangan    109
# 833        dibawah    109
# 834       sertakan    109
# 835         kasual    108
# 836          lapis    108
# 837             es    108
# 838           grab    108
# 839    menenangkan    108
# 840       estimasi    108
# 841       disimpan    108
# 842        newborn    107
# 843             id    107
# 844          garis    107
# 845           nvme    107
# 846          popok    107
# 847        langkah    107
# 848           kado    106
# 849      minimalis    106
# 850          matte    106
# 851        setrika    106
# 852        koleksi    106
# 853          glass    106
# 854           side    106
# 855           60cm    106
# 856       menambah    106
# 857       matahari    106
# 858      treadmill    105
# 859           polo    105
# 860          motor    105
# 861        ekstrak    105
# 862      frekuensi    105
# 863   ketersediaan    105
# 864       didesain    105
# 865           gold    104
# 866      gantungan    104
# 867            mic    104
# 868           meja    104
# 869          rajut    103
# 870          lemon    103
# 871          kamar    103
# 872           make    103
# 873          merek    103
# 874          hidup    103
# 875        kecuali    103
# 876          https    103
# 877          lahir    102
# 878       karakter    102
# 879          helio    102
# 880         lotion    102
# 881    profesional    102
# 882          siang    102
# 883            can    102
# 884        dipilih    102
# 885          dasar    102
# 886      permukaan    102
# 887           resi    102
# 888           kaya    102
# 889           slim    101
# 890         simple    101
# 891          kipas    101
# 892           goto    101
# 893              i    101
# 894           gigi    101
# 895           batu    101
# 896  menghilangkan    101
# 897          tekan    101
# 898        sweater    100
# 899        cokelat    100
# 900          pouch    100
# 901          speed    100
# 902      polyester    100
# 903        tekanan    100
# 904       graphics    100
# 905           jasa    100
# 906           usus     99
# 907           jari     99
# 908   menyesuaikan     99
# 909         pabrik     99
# 910            www     99
# 911          cowok     98
# 912           bola     98
# 913        silikon     98
# 914          basah     98
# 915       pengawet     98
# 916         sarung     98
# 917        jaminan     98
# 918          mulus     98
# 919       internal     98
# 920            gpu     98
# 921     resolution     98
# 922        optimal     98
# 923        sensasi     98
# 924        orderan     98
# 925          beeme     97
# 926        blender     97
# 927          multi     97
# 928           topi     97
# 929          sirup     97
# 930           kota     97
# 931         dijual     97
# 932     menawarkan     97
# 933          ramah     97
# 934        penjual     97
# 935            aja     97
# 936          120hz     96
# 937       cleanser     96
# 938        dikemas     96
# 939      transaksi     96
# 940         cortex     96
# 941        selimut     95
# 942     waterproof     95
# 943         kulkas     95
# 944    memperbaiki     95
# 945             x1     95
# 946       berbahan     95
# 947        gerakan     95
# 948            2cm     95
# 949       petunjuk     95
# 950           gift     94
# 951           acne     94
# 952         remote     94
# 953         kacang     94
# 954          segel     94
# 955         diskon     94
# 956         stabil     94
# 957          cewek     93
# 958           balm     93
# 959           slip     93
# 960          sudut     93
# 961          musim     93
# 962   perlindungan     93
# 963        melatih     93
# 964           uang     93
# 965          aroma     93
# 966         apapun     93
# 967         akibat     93
# 968         update     93
# 969       oversize     92
# 970         import     92
# 971         tablet     92
# 972           ikan     92
# 973        support     92
# 974            tua     92
# 975        telapak     92
# 976          input     92
# 977        efisien     92
# 978       komponen     92
# 979         tujuan     92
# 980           ragu     92
# 981        infinix     91
# 982            low     91
# 983       mediatek     91
# 984         daging     91
# 985          kunci     91
# 986         online     91
# 987             pp     91
# 988    fingerprint     91
# 989     lingkungan     91
# 990         setara     91
# 991   menghasilkan     91
# 992    menyediakan     91
# 993          karna     91
# 994          biaya     91
# 995         jangka     91
# 996         realme     90
# 997         xiaomi     90
# 998          basic     90
# 999            pad     90>

# %% [markdown]
# cek beberapa kata

# %%
keywords = ["sd", "lp", "w", "it", "pp"]

# Gabungkan semua teks dari kolom-kolom yang dianalisis
all_texts = []
for col in cols_to_check:
    all_texts.extend(df[col].dropna().astype(str).tolist())

# Untuk setiap keyword, cari kalimat/fragmen yang mengandungnya
for kw in keywords:
    print(f"\n=== Contoh kemunculan '{kw}' ===")
    found = 0
    for t in all_texts:
        t_lower = t.lower()
        if kw in t_lower.split():
            print("-", t)
            found += 1
        elif f" {kw}" in t_lower or f"{kw} " in t_lower:
            print("-", t)
            found += 1
        if found >= 5:
            break
    if found == 0:
        print("Tidak ditemukan.")
# Out:
# === Contoh kemunculan 'sd' ===
# - Komputer All in One Baru, Intel Core i7 Gen ke-6, RAM 16GB + SSD 512GB Gratis Keyboard+mouse
# - Set PC Komputer Intel Core i5-12400 Gen-12 RAM 8GB SSD || Frameless
# - ASUS PC Desktop P500MV Intel Core i3 1315 RAM 8 GB SSD 512 GB Windows 11 + LED Monitor 21.5 Inch
# - Set PC Slim Intel Core i5-14400 Gen-14 RAM 8GB SSD || Frameless
# - Komputer Rakitan i5 3470 | Ram 8GB HDD 1TB SSD 120GB| Kantor Sekolah
#
# === Contoh kemunculan 'lp' ===
# - COD Original JBL Phantom Wireless Bluetooth Headset LP35, Ringan dan Nyaman, Cocok untuk Ponsel Android dan iphone, Panggilan HD, Musik In-Ear Berkualitas Tinggi, Headphone Gaming Tidur,TWS
# - UMUM
# Tahun Rilis 2024
# Jaringan 2G, 3G, 4G, 5G
# SIM Card Single SIM
# eSIM Ya
#
# BODY
# Dimensi 160.9 x 77.8 x 7.8 mm
# Berat 199 gram
# Ketahanan IP68
# Fitur Lainnya
# - Tahan debu seluruh sisi dan tahan air hingga kedalaman 6 m selama 30 menit
# - Material: kaca buatan Corning (bagian depan dan belakang), aluminium (frame)
#
# LAYAR UTAMA
# Jenis Super Retina XDR OLED
# Ukuran 6.7 inci
# Refresh Rate 60 Hz
# Resolusi 1290 x 2796 piksel
# Rasio 19.5:9
# Kerapatan 460 ppi
# Proteksi Ceramic Shield Glass
# Fitur Lainnya
# - HDR10, Dolby Vision
# - Tingkat kecerahan: 1000 nit (khas), 2000 nit (HBM)
# - Rasio layar ke bodi 88%
#
# HARDWARE
# Chipset Apple A18
# CPU Hexa-core (2x3.89 GHz+ 4x2.2 GHz)
# GPU Apple GPU (5-core graphics)
#
# MEMORI
# RAM 8 GB
# Jenis RAM LPDDR5x
# Memori Internal 128 GB, 256 GB, 512 GB
# Jenis Memori NVMe
# Memori Eksternal Tidak Ada
#
# KAMERA UTAMA
# Jumlah Kamera 3
# Konfigurasi 48 MP • wide • f/1.6 12 MP • ultrawide • f/2.2
# Fitur Wide: dual pixel PDAF, sensor-shift OIS; Ultrawide: FoV 120˚; dual pixel PDAF; Umum: Dual-LED dual-tone flash, HDR (photo/panorama); Video: Hingga 4K@24/25/30/60fps, HDR, Dolby Vision HDR (hingga 60 FPS), perekaman suara stereo, gyro-EIS
#
# KAMERA DEPAN
# Jumlah Kamera 1
# Konfigurasi 12 MP • wide • f/1.9
# Fitur PDAF, SL 3D (sensor kedalaman/biometriks), HDR, Video: Hingga 4K@24/25/30/60fps, gyro-EIS
#
# KONEKTIVITAS
# WLAN Wi-Fi 802.11 a/b/g/n/ac/6/7, dual-band, hotspot
# Bluetooth 5.3, A2DP, LE
# Infrared Tidak Ada
# NFC Ada
# GPS GPS (L1+L5), GLONASS, GALILEO, BDS, QZSS, NavIC
# USB Tipe-C 2.0, DisplayPort
#
# BATERAI
# Jenis Li-Ion
# Kapasitas 4674 mAh
# Fitur Pengisian cepat 20W PD 2.0 (klaim 50% dalam 30 menit). pengisian nirkabel MagSafe 25W, pengisian nirkabel Qi2 15W, pengisian terbalik 4.5W
#
# FITUR
# OS (Saat Rilis) iOS 18
# Sensor Face ID, akselerometer, cahaya, giroskop, proksimitas, kompas, barometer, UWB 2, Emergency SOS via satellite
# Jack 3.5mm Tidak Ada
# Warna Hitam, Putih, Pink, Teal, Ultramarine
# Fitur Lainnya - Speaker stereo
# - Dukungan Ultra Wideband 2 (UWB)
# - Dukungan pengiriman pesan darurat SOS via satelit
# - Fitur AI berbasiskan Apple MGIE AI
# - Apple Pay (Visa, MasterCard, AMEX certified)
# - UMUM
# Tahun Rilis 2024
# Jaringan 2G, 3G, 4G, 5G
# SIM Card Single SIM
# eSIM Ya
#
# BODY
# Dimensi 149.6 x 71.5 x 8.3 mm
# Berat 199 gram
# Ketahanan IP68
# Fitur Lainnya
# - Tahan debu seluruh sisi dan tahan air hingga kedalaman 6 m selama 30 menit
# - Material: kaca buatan Corning (bagian depan dan belakang), titanium grade 5 (frame)
#
# LAYAR UTAMA
# Jenis LTPO Super Retina XDR OLED
# Ukuran 6.3 inci
# Refresh Rate 120 Hz
# Resolusi 1206 x 2622 piksel
# Rasio 19.5:9
# Kerapatan 458 ppi
# Proteksi Ceramic Shield Glass
# Fitur Lainnya
# - HDR10, Dolby Vision
# - Rasio layar ke bodi 90.9%
# - Always-On Display
#
# HARDWARE
# Chipset Apple A18 Pro
# CPU Hexa-core (2x3.4.05 GHz+ 4x2.42 GHz)
# GPU Apple GPU (6-core graphics)
#
# MEMORI
# RAM 8 GB
# Jenis RAM LPDDR5x
# Memori Internal 256 GB, 512 GB, 1 TB
# Jenis Memori NVMe
# Memori Eksternal Tidak Ada
#
# KAMERA UTAMA
# Jumlah Kamera 3
# Konfigurasi 48 MP • wide • f/1.8 12 MP • periscope telephoto • f/2.8 48 MP • ultrawide • f/2.2 Fitur Wide: dual pixel PDAF, sensor-shift OIS; Ultrawide: FoV 120˚; dual pixel PDAF; Telefoto periskop: dual-pixel PDAF, sensor-shift OIS; 5x zoom optis; Umum: Dual-LED dual-tone flash, HDR (photo/panorama); Video: Hingga 4K@24/25/30/60fps, Cinematic mode (4K@30fps), gyro-EIS; 10-bit HDR, Dolby Vision HDR (hingga 60 FPS), ProRes, 3D (spasial video), perekaman suara stereo; Sensor depth: ToF 3D LiDAR Scanner
#
# KAMERA DEPAN
# Jumlah Kamera 1
# Konfigurasi 12 MP • wide • f/1.9
# Fitur PDAF, OIS, SL 3D (sensor kedalaman/biometriks), HDR, Video: Hingga 4K@24/25/30/60fps, Cinematic mode (4K@30fps), gyro-EIS
#
# KONEKTIVITAS
# WLAN Wi-Fi 802.11 a/b/g/n/ac/6e/7, dual-band, hotspot
# Bluetooth 5.3, A2DP, LE
# Infrared Tidak Ada
# NFC Ada
# GPS GPS (L1+L5), GLONASS, GALILEO, BDS, QZSS, NavIC
# USB Tipe-C 3.2 Gen 2, DisplayPort
#
# BATERAI
# Jenis Li-Ion
# Kapasitas 3582 mAh
# Fitur Pengisian cepat 20W PD 2.0 (klaim 50% dalam 30 menit). pengisian nirkabel MagSafe 25W, pengisian nirkabel Qi2 15W, pengisian terbalik 4.5W
#
# FITUR
# OS (Saat Rilis) iOS 18
# Sensor Face ID, akselerometer, cahaya, giroskop, proksimitas, kompas, barometer, UWB 2, Emergency SOS via satellite
# Jack 3.5mm Tidak Ada
# Warna Black Titanium, White Titanium, Natural Titanium, Desert Titanium
# Fitur Lainnya
# - Speaker stereo
# - Dukungan Ultra Wideband 2 (UWB)
# - Dukungan pengiriman pesan darurat SOS via satelit
# - Fitur AI berbasiskan Apple MGIE AI
# - Apple Pay (Visa, MasterCard, AMEX certified)
# - [Fitur Produk]
# Bodi tahan debu dan air, lulus standar uji militer
# Layar Pro IGZO OLED dengan refresh rate hingga 240 Hz
# SoC berperforma tinggi Snapdragon 7+ Gen 3
# Kamera belakang ganda 50.3 MP yang di-tuning oleh Leica
# Baterai 5000 mAh, disokong fast charging 30 Watt
# UMUM
# Tahun Rilis 2024
# Jaringan 2G, 3G, 4G, 5G
# SIM Card Single SIM
# eSIM Ya
# BODY
# Ketahanan IP68, MIL-STD-810G
# Fitur Lainnya - Tahan debu dan tahan air (hingga kedalaman 1 m selama 30 menit)
# - Lulus sertifikasi uji standar militer
# LAYAR UTAMA
# Jenis Pro IQZO OLED
# Ukuran 6.5 inci
# Refresh Rate 240 Hz
# Resolusi 1080 x 2340 piksel
# Rasio 20:9
# Kerapatan 396 ppi
# Proteksi -
# Fitur Lainnya - 1.07 miliar warna, Dolby Vision
# - Tingkat kecerahan 1500 nit (puncak)
# HARDWARE
# Chipset Qualcomm Snapdragon 7+ Gen 3
# CPU Octa-core (1x2.8 GHz Cortex-X4 & 4x2.6 GHz Cortex-A720 & 3x1.8 GHz Cortex-A520)
# GPU Adreno 732
# MEMORI
# RAM 12 GB
# Jenis RAM LPDDR5X
# Memori Internal 256 GB
# Jenis Memori UFS 4.0
# Memori Eksternal Ada (Slot Khusus)
# KAMERA UTAMA
# Jumlah Kamera 2
# Konfigurasi
# 50.3 MP • wide • f/1.9
# 50.3 MP • ultrawide • f/2.2
# Fitur Wide: PDAF, OIS; Ultrawide: FoV 122˚; Umum: LED flash, HDR, panorama, sistem optik Leica, Video: 4K@30/60fps, 1080p@30/60fps, gyro-EIS
# KAMERA DEPAN
# Jumlah Kamera 1
# Konfigurasi
# 50.3 MP • wide • f/2.2
# Fitur Video: 1080p@30fps
# KONEKTIVITAS
# WLAN Wi-Fi 802.11 a/b/g/n/ac/6e/7, tri-band, Wi-Fi Direct
# Bluetooth 5.4, A2DP, LE, aptX HD, aptX Adaptive, aptX Lossless
# Infrared Tidak Ada
# NFC Ada
# GPS GPS, A-GPS, GLONASS, GALILEO, BDS, QZSS
# USB Tipe-C 2.0, USB On-The-Go
# BATERAI
# Jenis Li-Po
# Kapasitas 5000 mAh
# Fitur Pengisian cepat 30W
# FITUR
# OS (Saat Rilis) Android 14
# Sensor Fingerprint (optik, di bawah permukaan layar), akselerometer, cahaya, giroskop, proksimitas, kompas
# Jack 3.5mm Tidak Ada
# Warna Hijau, Putih
# Fitur Lainnya Speaker stereo
# - Unit ready tidak po
# langsung kirim
# sudah ada bahasa Indonesia
# Dualsim
# imei sudah terdaftar di website beacukai
# jadi semua provider sim di Indonesia bisa
# untuk sinyal atau imei garansi selamanya
# free earphone bluetooth
#
#
# fitur unggulan
# -dual screen cocok untuk live streaming
# -baterai besar di 12.800 mah dan pengecasan di 66watt
# - speaker 4watt seperti speaker portabel
#
#
#
#
#
#
# Ulefone Armor 30 Pro adalah ponsel tangguh (rugged phone) yang dirilis pada April 2025. Ponsel ini dirancang untuk kondisi ekstrem dan memiliki fitur-fitur yang menonjol.
# Berikut adalah spesifikasi Ulefone Armor 30 Pro secara lengkap:
# Desain & Layar:
#  * Bodi: Tangguh, tahan air, debu, dan guncangan dengan sertifikasi IP68/IP69K dan MIL-STD-810H. Dimensi 181.3 x 84.9 x 21.2 mm dan berat 509 gram.
#  * Layar Utama: IPS LCD 6.95 inci, resolusi FHD+ (2460 x 1080 piksel) dengan refresh rate 120Hz. Kecerahan puncak hingga 700 nits. Dilindungi Gorilla Glass 5.
#  * Layar Sekunder: 3.4 inci di bagian belakang dengan resolusi 412 x 960 piksel dan multi-touch 5 titik. Berfungsi untuk notifikasi, pintasan, dan sebagai monitor saat selfie/vlogging.
#  * Speaker: Ultra-loud 118dB dengan diameter 28mm dan rongga suara 9cc, menghasilkan suara 4W yang kuat dan jernih. Dilengkapi Infinite Halo 2.0 yang bisa menyesuaikan dengan ritme musik atau video.
# Performa:
#  * Chipset: MediaTek Dimensity 7300X 5G (fabrikasi 4nm, Octa-core hingga 2.5GHz).
#  * GPU: Arm Mali-G615 MC2.
#  * RAM: 16GB LPDDR5 (dapat diperluas secara virtual hingga total 32GB).
#  * Penyimpanan Internal: 512GB UFS 3.1.
#  * Slot Kartu Memori: microSDXC hingga 2TB.
#  * Sistem Operasi: Android 14 (direncanakan dapat ditingkatkan ke Android 15).
# Kamera:
#  * Kamera Belakang Utama: 50MP dengan sensor ultra-besar OMNIVISION O50H 1/1.3″.
#  * Kamera Night Vision: 64MP dengan empat LED inframerah untuk visibilitas dalam gelap total (jarak efektif sekitar 18-20m).
#  * Kamera Ultra-lebar: 50MP.
#  * Kamera Depan: 32MP.
#  * Fitur Kamera: Dukungan perekaman video 4K, Electronic Image Stabilization (EIS), mode malam, HDR.
# Baterai:
#  * Kapasitas: 12800 mAh.
#  * Pengisian Cepat: 66W.
#  * Pengisian Balik (Reverse Charging): 10W (dapat berfungsi sebagai power bank).
# Fitur Lainnya:
#  * Konektivitas: 5G, Wi-Fi, Bluetooth, NFC, GPS presisi tinggi.
#  * Sensor: Sidik jari, Face unlock.
#  * Port: USB Type-C.
#  * Fit
#
#
#
#
#
#
#
#
#
#
#
#
# ur Tambahan: Dual SIM, tombol fungsi khusus.
#
# === Contoh kemunculan 'w' ===
# - ENOVE - Device Stylish 3 Warna | Bisa Dijeda | Compact & Elegan
# - LIGE sub-merek FOXBOX Jam Tangan Pria Fashion Baru Jam Tangan Silikon Olahraga Kasual Bercahaya Tahan Air Elektronik Digital  Watches
# - [EXCLUSIVE DADAHAPHONE] MIXIO MP-08 5000mAh Powerbank Mini 20W With Kabel Fast Charging Lightning & Type C Compatible For Iphone/Android
# - 【Ready+Bisa COD】Advance Speaker Bluetooth Karaoke TWS 8inch+1xMic Wireless 821
# - SOARFLY 60000mAh 22.5W Outdoor Power Pengisian Cepat Luar Ruangan Power Bank Kapasitas Besar Lampu Berkemah Portabel Dengan 4 Kabel Powerbank Elektronik
#
# === Contoh kemunculan 'it' ===
# - Pop It Elektronik Push Bubble Game Console Fidget Toys LED Anti Stress
# - PAKET KOMPLIT Mesin Cukur Rambut Kumis Jenggot Kemei KM - 1407 / Alat Cukur Rambut Cas 1set Komplit BONUS GUNTING DAN SILET CUKUR DAN SISIR
# - Mainan Pop It Elektronik Mainan Anak Game POP IT ELEKTRIK Musik Puzzle Anak
# - iFixit Pro Tech Toolkit, untuk Laptop, Smartphone & Elektronik lainnya
# - iFixit Essential Electronics Toolkit, untuk Peralatan Elektronik
#
# === Contoh kemunculan 'pp' ===
# - Pp Fashion-Setelan Hotpants Oversize One Set Kaos Spandek Premium Atasan Wanita Celana Pendek Setelan Kaos V-Neck Shorts Nyaman Lembut
# - KOI Dot Bayi Botol Susu 260Ml 125Ml Botol susu bayi newborn BPA Free Botol Minum Bayi PP Botol Minum Anak BPA FREE
# - Momosee Botol Susu Bayi / Baby Bottle PP Nano Perak (WIDENECK) 3IN1 Dot + Sippy + Straw 240ML/300ML BPA FREE BB15 Minum Sedotan Accessories
# - Momwell BPS06 Botol Susu bayi PPSU BPA Free Anti Bocor Botol Minum Bayi 160ML/240ML Dot Bayi Botol
# - Dr.isla PP15 Botol Bayi Newborn 0-3 Bulan Botol Bayi Newborn Anti Kolik Mulut Lebar 150ml Minum Bottle

# %% [markdown]
# ## Most Common Words Data Scrape 2 (Product's Reviews)

# %%
import os
os.listdir()
# Out:
# ['data',
#  'dictionary.ipynb',
#  'README.md',
#  'requirements.txt',
#  'scraper_tokopedia.ipynb',
#  'scraper_tokped.py']

# %%
# --- load reviews dari CSV ---
df_reviews = pd.read_csv("data/reviews_only.csv", encoding="utf-8")
texts = df_reviews["review"].dropna().astype(str).tolist()

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1676 entries, 0 to 1675
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   review  1676 non-null   object
# dtypes: object(1)
# memory usage: 13.2+ KB

# %%
all_words = []
for text in texts:
    words = re.findall(r"\w+", text.lower())
    for w in words:
        if w.isdigit():
            continue
        if w in stopwords_id:
            continue
        if len(w) == 1:
            continue
        all_words.append(w)

counter = Counter(all_words)
top_100 = counter.most_common(500)

for word, freq in top_100:
    print(word, ":", freq)
# Out:
# bagus : 573
# nya : 466
# sesuai : 419
# barang : 380
# cepat : 294
# pengiriman : 241
# banget : 232
# yg : 224
# produk : 207
# aman : 199
# semoga : 197
# bahan : 194
# seller : 172
# kualitas : 161
# beli : 136
# pesanan : 132
# pas : 130
# harga : 117
# enak : 111
# ya : 109
# cocok : 108
# packing : 104
# ga : 100
# awet : 98
# terimakasih : 97
# bgt : 97
# terima : 94
# rapi : 93
# bahannya : 93
# warna : 92
# alhamdulillah : 91
# kasih : 88
# mantap : 88
# paket : 87
# toko : 86
# gak : 81
# suka : 80
# amanah : 74
# respon : 72
# dgn : 71
# barangnya : 70
# ramah : 70
# oke : 68
# order : 68
# ukuran : 68
# berfungsi : 67
# ok : 65
# udah : 63
# jg : 61
# anak : 61
# makasih : 60
# lumayan : 60
# kurir : 58
# tp : 56
# tebal : 55
# ori : 54
# deskripsi : 54
# sdh : 52
# diterima : 52
# gambar : 50
# coba : 50
# puas : 50
# sukses : 48
# rapih : 48
# adem : 46
# gk : 45
# aja : 44
# kali : 44
# thanks : 44
# lembut : 44
# fast : 43
# sampe : 42
# tas : 42
# nyaman : 41
# murah : 40
# pokoknya : 40
# cepet : 40
# ny : 39
# next : 39
# pake : 38
# hp : 38
# tipis : 38
# langsung : 37
# asli : 37
# keren : 37
# udh : 37
# sih : 36
# original : 35
# amp : 35
# tokopedia : 35
# selamat : 34
# tpi : 34
# pakai : 34
# kulit : 34
# mudah : 33
# penjual : 32
# desain : 32
# bb : 31
# bikin : 30
# pengirimannya : 30
# panas : 30
# dipakai : 30
# tebel : 30
# kemasan : 29
# pesan : 29
# kak : 29
# kokoh : 29
# dicoba : 28
# pengerjaan : 28
# deh : 28
# packaging : 28
# jahitan : 28
# cantik : 27
# super : 27
# images : 27
# langganan : 27
# tokonya : 27
# lengkap : 26
# kurirnya : 26
# pengemasan : 26
# lg : 26
# ekspektasi : 25
# cacat : 25
# recommended : 25
# segitu : 25
# ku : 25
# tdk : 24
# paketnya : 24
# good : 24
# nyampe : 24
# responsif : 24
# kondisi : 23
# dapet : 23
# pelayanan : 23
# foto : 23
# dah : 23
# https : 23
# bonus : 23
# sehat : 23
# kalo : 22
# rusak : 22
# baguss : 22
# yaa : 22
# warnanya : 22
# the : 22
# ukurannya : 22
# nyesel : 21
# ragu : 21
# hasilnya : 21
# sayang : 21
# pecah : 21
# halus : 21
# kuat : 21
# gitu : 20
# memuaskan : 20
# real : 20
# dateng : 20
# ngga : 20
# thank : 20
# proses : 20
# admin : 20
# obat : 20
# top : 19
# teman : 19
# belanja : 19
# jd : 19
# kecewa : 19
# it : 19
# berat : 19
# karakteristik : 19
# bener : 18
# co : 18
# si : 18
# bajunya : 18
# packingnya : 18
# olahraga : 18
# biar : 17
# utk : 17
# dr : 17
# segel : 17
# kirim : 17
# cuman : 17
# karna : 17
# cakep : 17
# badan : 17
# tb : 17
# tasnya : 17
# produknya : 16
# kayak : 16
# penyok : 16
# maaf : 16
# dikit : 16
# dipake : 16
# rating : 16
# blm : 16
# model : 16
# dpt : 16
# gurih : 16
# dg : 15
# bgus : 15
# productreview : 15
# feedback_id : 15
# variant_name : 15
# message : 15
# review_age : 15
# user_full_name : 15
# user_url : 15
# response_message : 15
# response_created_text : 15
# videos : 15
# likes : 15
# min : 15
# best : 15
# gampang : 15
# baju : 15
# tau : 15
# berkualitas : 15
# free : 15
# exp : 15
# alat : 14
# lucu : 14
# lancar : 14
# bgs : 14
# sellernya : 14
# bintang : 14
# dikirim : 14
# gede : 14
# karet : 14
# you : 14
# kaya : 14
# size : 14
# isi : 14
# bubble : 14
# wrap : 14
# box : 14
# pedes : 14
# normal : 13
# gercep : 13
# buka : 13
# chat : 13
# performa : 13
# mantab : 13
# pokonya : 13
# kemarin : 13
# gan : 13
# rumah : 13
# celana : 13
# beda : 13
# nggak : 13
# realpict : 13
# ringan : 13
# expired : 13
# minum : 13
# plastik : 13
# bnget : 12
# salah : 12
# smoga : 12
# and : 12
# www : 12
# com : 12
# stok : 12
# net : 12
# img : 12
# cache : 12
# product : 12
# sy : 12
# putih : 12
# rekomendasi : 12
# nih : 12
# sembuh : 12
# pedas : 12
# renyah : 12
# ni : 11
# masak : 11
# mendarat : 11
# abis : 11
# overall : 11
# lecet : 11
# kardus : 11
# kg : 11
# bentuk : 11
# tiktok : 11
# harganya : 11
# takut : 11
# mantul : 11
# mksh : 11
# cm : 11
# sumpah : 11
# seler : 11
# diskon : 11
# date : 11
# cek : 11
# bumbu : 11
# trims : 10
# mah : 10
# trus : 10
# hitam : 10
# mudah2an : 10
# garansi : 10
# gpp : 10
# tutup : 10
# paking : 10
# keliatan : 10
# mewah : 10
# in : 10
# vivo : 10
# update : 10
# untung : 10
# mudahan : 10
# hpnya : 10
# dtg : 10
# seneng : 10
# alhamdulilah : 10
# dn : 10
# hehe : 10
# bngt : 10
# ganti : 10
# brg : 10
# tolong : 10
# modelnya : 10
# kasar : 10
# allah : 10
# worth : 10
# muat : 10
# pict : 10
# isinya : 10
# air : 10
# bersahabat : 10
# kapasitas : 9
# jenis : 9
# kualitasnya : 9
# trimakasih : 9
# kk : 9
# packingan : 9
# link : 9
# tetep : 9
# kalinya : 9
# krn : 9
# cream : 9
# terjangkau : 9
# live : 9
# nerawang : 9
# repeat : 9
# tangan : 9
# ak : 9
# kainnya : 9
# smg : 9
# emang : 9
# klo : 9
# botol : 9
# glow : 9
# daya : 8
# on : 8
# tahan : 8
# kejernihan : 8
# lensa : 8
# orang : 8
# kerusakan : 8
# kirain : 8
# material : 8
# item : 8
# membantu : 8
# bermanfaat : 8
# berkah : 8
# pesenan : 8
# pokok : 8
# bangett : 8
# penjualnya : 8
# berbelanja : 8
# terbaru : 8
# yah : 8
# kendala : 8
# pesen : 8
# harapan : 8
# rekomen : 8
# video : 8
# tujuan : 8
# umur : 8
# habis : 8
# manis : 8
# hancur : 8
# lupa : 8
# susah : 8
# minggu : 8
# xl : 8
# lihat : 8
# doang : 8
# sm : 8
# simple : 8
# kain : 8
# dlm : 8
# manfaat : 8
# sma : 8
# nyoba : 8
# gratis : 8
# bs : 8
# bumbunya : 8
# cas : 7
# no : 7
# power : 7
# dibuka : 7
# rekomended : 7
# hasil : 7
# cpt : 7
# baget : 7
# parah : 7
# abang : 7
# tks : 7
# bagikan : 7
# dikemas : 7
# tes : 7
# msh : 7
# kekurangan : 7
# elegan : 7
# makan : 7
# nyangka : 7
# responnya : 7
# pembelian : 7
# ditoko : 7
# mahal : 7
# bagusss : 7
# segini : 7
# cerah : 7
# ambil : 7
# kek : 7
# pic : 7
# knp : 7
# dikasih : 7
# bayi : 7
# kwalitas : 7
# mksih : 7
# mencerahkan : 7
# kesehatan : 7
# bjfkpx : 7
# jpg : 7
# aq : 6
# bank : 6
# charging : 6
# nyala : 6
# terang : 6
# keterangan : 6
# detail : 6
# kadang : 6
# laptop : 6
# pemakaian : 6
# lgi : 6
# tersegel : 6
# pilih : 6
# minus : 6
# bocor : 6
# sehari : 6
# online : 6
# mulus : 6
# thx : 6
# resmi : 6
# indonesia : 6
# mengecewakan : 6
# siang : 6
# tinggal : 6
# terbaik : 6
# uda : 6
# belom : 6
# kakak : 6
# anakku : 6
# ngak : 6
# murahan : 6
# aga : 6
# ka : 6
# an : 6
# bonusnya : 6
# pc : 6
# mouse : 6
# keyboard : 6
# jam : 6
# response : 6
# sebagus : 6
# gtu : 6
# pcs : 6
# mohon : 6
# quality : 6
# gini : 6
# kegedean : 6
# masuk : 6
# review : 6
# kebesaran : 6
# ms : 6
# shop : 6
# to : 6
# pink : 6
# jdi : 6
# enk : 6
# bahanya : 6
# promo : 6
# empuk : 6
# wangi : 6
# time : 6
# namanya : 6
# pengemasannya : 6
# beneran : 6
# makanan : 6

# %%
# top_100 is a list of tuples (word, freq)
df_top_words2 = pd.DataFrame(top_100, columns=['word', 'count'])
df_top_words2.head(40)
# Out:
#              word  count
# 0           bagus    573
# 1             nya    466
# 2          sesuai    419
# 3          barang    380
# 4           cepat    294
# 5      pengiriman    241
# 6          banget    232
# 7              yg    224
# 8          produk    207
# 9            aman    199
# 10         semoga    197
# 11          bahan    194
# 12         seller    172
# 13       kualitas    161
# 14           beli    136
# 15        pesanan    132
# 16            pas    130
# 17          harga    117
# 18           enak    111
# 19             ya    109
# 20          cocok    108
# 21        packing    104
# 22             ga    100
# 23           awet     98
# 24    terimakasih     97
# 25            bgt     97
# 26         terima     94
# 27           rapi     93
# 28       bahannya     93
# 29          warna     92
# 30  alhamdulillah     91
# 31          kasih     88
# 32         mantap     88
# 33          paket     87
# 34           toko     86
# 35            gak     81
# 36           suka     80
# 37         amanah     74
# 38         respon     72
# 39            dgn     71

# %% [markdown]
# ## Most Common Words from both

# %%
# Gabungkan kedua DataFrame top words
df_top_words_combined = pd.concat([df_top_words1, df_top_words2])
df_top_words_combined = df_top_words_combined.groupby('word', as_index=False)['count'].sum()
df_top_words_combined = df_top_words_combined.sort_values(by='count', ascending=False).reset_index(drop=True)

df_top_words_combined.head(30)
# Out:
#           word  count
# 0       produk   4725
# 1           cm   4060
# 2        bahan   3329
# 3            x   2949
# 4       ukuran   2659
# 5       barang   2156
# 6        warna   2132
# 7        kulit   2104
# 8        cocok   1886
# 9        paket   1843
# 10        bayi   1732
# 11        size   1716
# 12  pengiriman   1689
# 13        anak   1578
# 14      celana   1569
# 15      sesuai   1516
# 16     lingkar   1435
# 17       mudah   1400
# 18      wanita   1377
# 19     garansi   1344
# 20        aman   1286
# 21      nyaman   1283
# 22        pria   1258
# 23         tas   1213
# 24        alat   1162
# 25    membantu   1147
# 26        toko   1075
# 27         jam   1067
# 28        baju   1066
# 29         air   1055

# %% [markdown]
# ## **Detect Acronyms**

# %%
import re
import pandas as pd

# === whitelist akronim/unit yang valid (boleh kamu tambah terus) ===
SEED = {
    # --- umum / teknis ---
    "sku", "cod", "oem", "ori", "sni", "bpom", "oem", "hires", "gsm", "bpa",
    "bb", "dll", "pcs", "jpg",

    # power / elektronik
    "hz", "khz", "mhz", "ghz",
    "mah", "ac", "pd", "qc",

    # data
    "kb", "mb", "gb", "tb",

    # konektivitas & antarmuka
    "usbc", "typec", "hdmi", "vga", "bt", "ble", "nfc",
    "ir", "lte", "volte", "sim", "esim",

    # komponen / penyimpanan
    "ssd", "hdd",

    # layar / gambar
    "lcd", "led", "oled", "amoled", "ips",
    "hdr", "fps", "rgb", "srgb", "ppi", "dpi", "mp", "hd",

    # ukuran / berat / volume
    "cm", "mm", "m", "km", "kg", "g", "gr", "l", "ml", "oz", "lb", "lbs", "psi",

    # fashion (size code + ukuran lokal)
    "xs", "s", "m", "l", "xl", "xxl", "xxxl", "xxxs",
    "ld", "lp", "pb",

    # kecantikan / kesehatan / makanan
    "spf", "pa", "uv", "uva", "uvb", "ph",
    "uht", "ppm", "mg", "mcg", "iu", "kcal", "cal",

    # hp / jaringan
    "nfc",

    # audio
    "tws", "anc", "enc", "aac", "sbc", "ldac",

    # makanan / minuman / label
    "mfg", "exp",
}


RULES = [
    # huruf saja 2–5 -> harus ada di SEED (biar kata umum gak ikut)
    ("alpha_short_seeded", re.compile(r"^[a-z]{2,5}$")),

    # huruf+angka 2–8 (ip67, 1080p, 5g, 34b bra, a4, b5, 256gb, uk9)
    ("alnum_mixed", re.compile(r"^(?=.*[a-z])(?=.*\d)[a-z0-9]{2,8}$")),

    # angka + unit huruf (10cm, 15ml, 230v, 65w, 500gb)
    ("num_unit", re.compile(r"^\d{1,4}[a-z]{1,4}$")),

    # resolusi / label p (720p, 1080p, 4k -> dianggap alnum_mixed tapi ini khusus biar jelas)
    ("resolution_p", re.compile(r"^\d{3,4}p$|^[2348]k$")),

    # dimensi 2D/3D (20x30, 200x200x50)
    ("dimension", re.compile(r"^\d{1,4}x\d{1,4}(x\d{1,4})?$")),

    # ukuran fashion (override 1-huruf S/M/L) -> valid
    ("size_code", re.compile(r"^(xs|s|m|l|xl|xxl|xxxl|xxxs)$")),

    # rating proteksi air (ipx7, ipx8) -> kadang tidak di SEED semua
    ("ipx_rating", re.compile(r"^ipx[0-8]$")),
]

# (opsional) stopwords domain: kata umum e-commerce yang ingin dibuang
DOMAIN_STOP = {
    "bahan","warna","ukuran","size","anak","pria","wanita","bayi","toko",
    "alat","jam","aman","kaos","harga","wajah","berat","dada","lebar",
    "video","isi","baju","tas","paket","cocok","mudah","barang","produk"
}

def detect_candidates(df_words: pd.DataFrame, min_count: int = 20) -> pd.DataFrame:
    rows = []
    for _, row in df_words.iterrows():
        w = str(row["word"]).lower()
        c = int(row["count"])

        if c < min_count:
            continue
        if w in DOMAIN_STOP:
            continue
        # hanya token alnum (sudah cocok dengan cara kamu bikin df_top_words)
        if not re.fullmatch(r"[a-z0-9]+", w):
            continue

        matched = None
        for name, rx in RULES:
            if not rx.match(w):
                continue
            if name == "alpha_short_seeded" and w not in SEED:
                # huruf pendek wajib ada di SEED (hindari 'bahan', 'warna', dst)
                continue
            matched = name
            break

        # kalau belum match apa-apa & token 1 huruf (bukan S/M/L), skip
        if not matched:
            continue

        rows.append({"word": w, "count": c, "rule": matched})

    return (
        pd.DataFrame(rows)
        .sort_values(["count","word"], ascending=[False, True])
        .reset_index(drop=True)
    )

# pakai:
df_acronyms = detect_candidates(df_top_words_combined, min_count=20)
df_acronyms.head(40)
# Out:
#      word  count                rule
# 0      cm   4060  alpha_short_seeded
# 1       l    913           size_code
# 2       m    825           size_code
# 3      kg    761  alpha_short_seeded
# 4     pcs    734  alpha_short_seeded
# 5      xl    678  alpha_short_seeded
# 6      bb    591  alpha_short_seeded
# 7     ssd    515  alpha_short_seeded
# 8     8gb    514         alnum_mixed
# 9    bpom    503  alpha_short_seeded
# 10     ld    498  alpha_short_seeded
# 11      s    472           size_code
# 12     1x    416         alnum_mixed
# 13     ml    406  alpha_short_seeded
# 14    xxl    387  alpha_short_seeded
# 15    dll    384  alpha_short_seeded
# 16    sim    382  alpha_short_seeded
# 17     i5    372         alnum_mixed
# 18  256gb    350         alnum_mixed
# 19    led    349  alpha_short_seeded
# 20    cod    318  alpha_short_seeded
# 21     gb    309  alpha_short_seeded
# 22  128gb    308         alnum_mixed
# 23   16gb    294         alnum_mixed
# 24     mm    289  alpha_short_seeded
# 25     mp    282  alpha_short_seeded
# 26     hd    263  alpha_short_seeded
# 27    4gb    238         alnum_mixed
# 28    vga    232  alpha_short_seeded
# 29    5cm    225         alnum_mixed
# 30     i7    217         alnum_mixed
# 31     lp    208  alpha_short_seeded
# 32    ghz    206  alpha_short_seeded
# 33     5g    200         alnum_mixed
# 34  512gb    193         alnum_mixed
# 35    mah    184  alpha_short_seeded
# 36     gr    182  alpha_short_seeded
# 37    ori    172  alpha_short_seeded
# 38     i3    166         alnum_mixed
# 39    hdd    165  alpha_short_seeded

# %%
df_acronyms['word'].unique()
# Out:
# array(['cm', 'l', 'm', 'kg', 'pcs', 'xl', 'bb', 'ssd', '8gb', 'bpom',
#        'ld', 's', '1x', 'ml', 'xxl', 'dll', 'sim', 'i5', '256gb', 'led',
#        'cod', 'gb', '128gb', '16gb', 'mm', 'mp', 'hd', '4gb', 'vga',
#        '5cm', 'i7', 'lp', 'ghz', '5g', '512gb', 'mah', 'gr', 'ori', 'i3',
#        'hdd', '1tb', 'ddr3', '2x', '4g', 'pb', 'lcd', '5mm', 'mg', '1kg',
#        'ddr4', '30fps', '64gb', '70cm', 'ips', 'hdmi', 'nfc', 'rgb',
#        '100cm', 'ac', '50cm', 'uv', '3pcs', '500gb', '1080p', '60cm',
#        '120hz', '2cm', 'x1'], dtype=object)

# %% [markdown]
# ### Making the dictionary (acronyms)

# %%
# buat skeleton dict dari hasil deteksi
acronym_dict = {w: "" for w in df_acronyms["word"].tolist()}

list(acronym_dict.items())[:20]
# Out:
# [('cm', ''),
#  ('l', ''),
#  ('m', ''),
#  ('kg', ''),
#  ('pcs', ''),
#  ('xl', ''),
#  ('bb', ''),
#  ('ssd', ''),
#  ('8gb', ''),
#  ('bpom', ''),
#  ('ld', ''),
#  ('s', ''),
#  ('1x', ''),
#  ('ml', ''),
#  ('xxl', ''),
#  ('dll', ''),
#  ('sim', ''),
#  ('i5', ''),
#  ('256gb', ''),
#  ('led', '')]

# %% [markdown]
# tambahin seeds yang blom ada disitu

# %%
# Tambahkan seed yang belum ada di acronym_dict, isi dengan string kosong
for s in SEED:
    if s not in acronym_dict:
        acronym_dict[s] = ""

list(acronym_dict.items())
# Out:
# [('cm', ''),
#  ('l', ''),
#  ('m', ''),
#  ('kg', ''),
#  ('pcs', ''),
#  ('xl', ''),
#  ('bb', ''),
#  ('ssd', ''),
#  ('8gb', ''),
#  ('bpom', ''),
#  ('ld', ''),
#  ('s', ''),
#  ('1x', ''),
#  ('ml', ''),
#  ('xxl', ''),
#  ('dll', ''),
#  ('sim', ''),
#  ('i5', ''),
#  ('256gb', ''),
#  ('led', ''),
#  ('cod', ''),
#  ('gb', ''),
#  ('128gb', ''),
#  ('16gb', ''),
#  ('mm', ''),
#  ('mp', ''),
#  ('hd', ''),
#  ('4gb', ''),
#  ('vga', ''),
#  ('5cm', ''),
#  ('i7', ''),
#  ('lp', ''),
#  ('ghz', ''),
#  ('5g', ''),
#  ('512gb', ''),
#  ('mah', ''),
#  ('gr', ''),
#  ('ori', ''),
#  ('i3', ''),
#  ('hdd', ''),
#  ('1tb', ''),
#  ('ddr3', ''),
#  ('2x', ''),
#  ('4g', ''),
#  ('pb', ''),
#  ('lcd', ''),
#  ('5mm', ''),
#  ('mg', ''),
#  ('1kg', ''),
#  ('ddr4', ''),
#  ('30fps', ''),
#  ('64gb', ''),
#  ('70cm', ''),
#  ('ips', ''),
#  ('hdmi', ''),
#  ('nfc', ''),
#  ('rgb', ''),
#  ('100cm', ''),
#  ('ac', ''),
#  ('50cm', ''),
#  ('uv', ''),
#  ('3pcs', ''),
#  ('500gb', ''),
#  ('1080p', ''),
#  ('60cm', ''),
#  ('120hz', ''),
#  ('2cm', ''),
#  ('x1', ''),
#  ('ppi', ''),
#  ('km', ''),
#  ('kcal', ''),
#  ('sbc', ''),
#  ('mhz', ''),
#  ('aac', ''),
#  ('oled', ''),
#  ('sni', ''),
#  ('lbs', ''),
#  ('dpi', ''),
#  ('sku', ''),
#  ('enc', ''),
#  ('tb', ''),
#  ('srgb', ''),
#  ('hdr', ''),
#  ('gsm', ''),
#  ('lb', ''),
#  ('amoled', ''),
#  ('anc', ''),
#  ('iu', ''),
#  ('bpa', ''),
#  ('xxxl', ''),
#  ('g', ''),
#  ('esim', ''),
#  ('mcg', ''),
#  ('uht', ''),
#  ('cal', ''),
#  ('ir', ''),
#  ('xs', ''),
#  ('tws', ''),
#  ('pa', ''),
#  ('ble', ''),
#  ('oem', ''),
#  ('typec', ''),
#  ('hires', ''),
#  ('fps', ''),
#  ('spf', ''),
#  ('khz', ''),
#  ('ph', ''),
#  ('jpg', ''),
#  ('ppm', ''),
#  ('psi', ''),
#  ('uva', ''),
#  ('lte', ''),
#  ('mb', ''),
#  ('oz', ''),
#  ('volte', ''),
#  ('kb', ''),
#  ('bt', ''),
#  ('qc', ''),
#  ('hz', ''),
#  ('usbc', ''),
#  ('xxxs', ''),
#  ('uvb', ''),
#  ('exp', ''),
#  ('mfg', ''),
#  ('pd', ''),
#  ('ldac', '')]

# %% [markdown]
# tampilin semua dict nya

# %%
# Tampilkan seluruh isi acronym_dict
for k, v in acronym_dict.items():
    print(f"{k}: {v}")
# Out:
# cm:
# l:
# m:
# kg:
# pcs:
# xl:
# bb:
# ssd:
# 8gb:
# bpom:
# ld:
# s:
# 1x:
# ml:
# xxl:
# dll:
# sim:
# i5:
# 256gb:
# led:
# cod:
# gb:
# 128gb:
# 16gb:
# mm:
# mp:
# hd:
# 4gb:
# vga:
# 5cm:
# i7:
# lp:
# ghz:
# 5g:
# 512gb:
# mah:
# gr:
# ori:
# i3:
# hdd:
# 1tb:
# ddr3:
# 2x:
# 4g:
# pb:
# lcd:
# 5mm:
# mg:
# 1kg:
# ddr4:
# 30fps:
# 64gb:
# 70cm:
# ips:
# hdmi:
# nfc:
# rgb:
# 100cm:
# ac:
# 50cm:
# uv:
# 3pcs:
# 500gb:
# 1080p:
# 60cm:
# 120hz:
# 2cm:
# x1:
# ppi:
# km:
# kcal:
# sbc:
# mhz:
# aac:
# oled:
# sni:
# lbs:
# dpi:
# sku:
# enc:
# tb:
# srgb:
# hdr:
# gsm:
# lb:
# amoled:
# anc:
# iu:
# bpa:
# xxxl:
# g:
# esim:
# mcg:
# uht:
# cal:
# ir:
# xs:
# tws:
# pa:
# ble:
# oem:
# typec:
# hires:
# fps:
# spf:
# khz:
# ph:
# jpg:
# ppm:
# psi:
# uva:
# lte:
# mb:
# oz:
# volte:
# kb:
# bt:
# qc:
# hz:
# usbc:
# xxxs:
# uvb:
# exp:
# mfg:
# pd:
# ldac:

# %%
# Gabungkan kandidat + seed
all_words = set(df_acronyms["word"].tolist()) | set(SEED)
df_all = pd.DataFrame({"word": list(all_words), "rule": [None]*len(all_words)})

# %%
import re

# --- seri/brand yang tidak ingin direplace (biarkan apa adanya) ---
EXCLUDE_SERIES = {"i3", "i5", "i7", "i9"}

# --- Units (singkat -> Bahasa Indonesia, tanpa tanda kurung) ---
UNITS = {
    # panjang/ukuran
    "cm":"centimeter", "mm":"milimeter", "m":"meter", "km":"kilometer",
    # massa/berat
    "kg":"kilogram", "g":"gram", "gr":"gram", "lb":"pound", "lbs":"pounds",
    # volume
    "l":"liter", "ml":"mililiter", "oz":"ons",
    # daya/kelistrikan & frekuensi
    "w":"watt",
    "hz":"hertz", "khz":"kilohertz", "mhz":"megahertz", "ghz":"gigahertz",
    # baterai & arus
    "mah":"miliampere jam", "dc":"arus searah", "ac":"arus bolak-balik",
    # data
    "kb":"kilobyte", "mb":"megabyte", "gb":"gigabyte", "tb":"terabyte",
    # tampilan/warna/ketajaman
    "ppi":"piksel per inci", "dpi":"titik per inci", 
    # tekanan
    "psi":"pon per inci persegi",
    # video/fps
    "fps":"frame per detik",
}

# --- Kode ukuran (fashion) ---
SIZES = {
    "xxxs":"Triple Ekstra Kecil",
    "xxl":"Double Ekstra Besar",
    "xxxl":"Triple Ekstra Besar",
    "xs":"Ekstra Kecil",
    "xl":"Ekstra Besar",
    "s":"Kecil",
    "m":"Sedang",
    "l":"Besar",
    # ukuran lokal populer
    "ld":"Lingkar Dada",
    "lp":"Lingkar Pinggang",
    "pb":"Panjang Baju",
}

# --- Akronim umum ---
ACRONYMS = {
    # konektivitas & antarmuka
    "usbc":"Universal Serial Bus Type-C",
    "typec":"Type-C",
    "bt":"Bluetooth",
    "ble":"Bluetooth Low Energy",
    "nfc":"Near Field Communication",
    "volte":"Voice over LTE",
    "sim":"Kartu SIM",
    "esim":"eSIM",

    # komponen/penyimpanan
    "ssd":"Solid State Drive",
    "hdd":"Hard Disk Drive",

    # layar/gambar
    "lcd":"Liquid Crystal Display",
    "led":"Light Emitting Diode",
    "oled":"Organic Light Emitting Diode",
    "amoled":"Active Matrix Organic Light Emitting Diode",
    "hdr":"High Dynamic Range",
    "rgb":"Red Green Blue",
    "srgb":"Standard Red Green Blue",
    "hd":"High Definition",

    # audio
    "tws":"True Wireless Stereo",
    "anc":"Active Noise Cancelling",
    "enc":"Environmental Noise Cancelling",
    "hires":"Hi-Res Audio",

    # codec audio
    "aac":"Advanced Audio Coding (codec audio)",
    "sbc":"Subband Codec (codec audio)",
    "ldac":"Low Latency Audio Codec (codec audio)",

    # pengisian
    "pd":"Power Delivery",
    "qc":"Quick Charge",

    # label/regulator/logistik
    "bpom":"Badan Pengawas Obat dan Makanan",
    "sni":"Standar Nasional Indonesia",
    "cod":"Bayar di tempat",
    "ori":"Asli",
    "oem":"Original Equipment Manufacturer",
    "sku":"Kode Stok",
    "gsm":"Gram per meter persegi (kertas)",

    # kecantikan/kesehatan/makanan

    "uv":"Sinar Ultraviolet",
    "uva":"Sinar Ultraviolet A",
    "uvb":"Sinar Ultraviolet B",
    "ppm":"Bagian per sejuta",
    "mg":"miligram",
    "mcg":"mikrogram",
    "iu":"International Unit",
    "kcal":"kilokalori",
    "cal":"kalori",
    "netto":"Berat bersih",
    "mfg":"Tanggal produksi",
    "exp":"Tanggal kedaluwarsa",

    # lain
    "pcs":"pieces",
    "bb":"berat badan",
    "dll":"dan lain-lain",
}

# --- Pola angka + unit (mendukung desimal & huruf) ---
NUM_UNIT_RE   = re.compile(r"^(\d+(?:[.,]\d+)?)([a-z]+)$", re.I)   
RES_P_RE      = re.compile(r"^(\d{3,4})p$", re.I)                  # 720p, 1080p
RES_K_RE      = re.compile(r"^(\d+(?:[.,]\d+)?)k$", re.I)          # 2k, 4k, 5.5k
MULT_TRAIL_RE = re.compile(r"^(\d+)x$", re.I)                      # 2x, 3x
MULT_LEAD_RE  = re.compile(r"^x(\d+)$", re.I)                      # x1, x2

# %%
def expand_token(word: str, rule: str | None) -> str:
    """
    Mengembalikan ekspansi BI untuk token 'word'.
    Jika tidak ada ekspansi relevan, return "" (artinya: biarkan kata asli).
    """
    w = (word or "").strip()
    if not w:
        return ""
    wl = w.lower()

    # 1) size code (prioritas jika rule= size_code)
    if rule == "size_code" and wl in SIZES:
        return SIZES[wl]

    # 2) resolusi khusus: 720p/1080p/2k/4k
    m = RES_P_RE.match(wl)
    if m:
        lines = m.group(1)
        return f"resolusi {lines}p"
    m = RES_K_RE.match(wl)
    if m:
        kval = m.group(1).replace(",", ".")
        return f"resolusi {kval}K"

    # 3) pengali X di belakang saja (2x)
    m = MULT_TRAIL_RE.match(wl)
    if m:
        return f"{m.group(1)} kali"

    # 4) angka + unit (128gb, 5cm, 1tb, 30fps, 500nits, 1.5l, 120hz)
    m = NUM_UNIT_RE.match(wl)
    if m:
        num, unit = m.groups()
        num = num.replace(",", ".")
        if unit in UNITS:
            return f"{num} {UNITS[unit]}"
        # unit tak dikenal -> jangan paksa
        return ""

    # 5) unit berdiri sendiri
    if wl in UNITS:
        return UNITS[wl]

    # 6) size code umum walau rule bukan size_code
    if wl in SIZES:
        return SIZES[wl]

    # 7) akronim umum
    if wl in ACRONYMS:
        return ACRONYMS[wl]

    # 8) default
    return ""

# %%
def build_acronym_dict(
    df_acronyms: pd.DataFrame,
    keep_unmapped: bool = False,
    exclude_series: set[str] = EXCLUDE_SERIES,
) -> dict[str, str]:
    """
    Membangun dictionary dari df_acronyms (kolom: 'word','rule').
    - keep_unmapped=False  -> hanya simpan entri yang punya ekspansi (value != "")
    - keep_unmapped=True   -> entri tanpa ekspansi tetap dimasukkan dengan value = token aslinya
    - token yang ada di exclude_series TIDAK di-replace (value = token aslinya jika keep_unmapped=True, atau di-skip jika False)
    """
    mapping: dict[str, str] = {}
    for _, r in df_acronyms[["word", "rule"]].drop_duplicates().iterrows():
        w = str(r["word"]).lower()
        rule = r["rule"] if "rule" in r and pd.notna(r["rule"]) else None

        if w in exclude_series:
            if keep_unmapped:
                mapping[w] = w  # biarkan apa adanya
            # jika tidak keep_unmapped, lewati
            continue

        expanded = expand_token(w, rule)

        if expanded:
            mapping[w] = expanded
        else:
            if keep_unmapped:
                mapping[w] = w  # tetap simpan, tapi tidak diubah

    return mapping

# %%
list(acronym_dict.items())
# Out:
# [('cm', ''),
#  ('l', ''),
#  ('m', ''),
#  ('kg', ''),
#  ('pcs', ''),
#  ('xl', ''),
#  ('bb', ''),
#  ('ssd', ''),
#  ('8gb', ''),
#  ('bpom', ''),
#  ('ld', ''),
#  ('s', ''),
#  ('1x', ''),
#  ('ml', ''),
#  ('xxl', ''),
#  ('dll', ''),
#  ('sim', ''),
#  ('i5', ''),
#  ('256gb', ''),
#  ('led', ''),
#  ('cod', ''),
#  ('gb', ''),
#  ('128gb', ''),
#  ('16gb', ''),
#  ('mm', ''),
#  ('mp', ''),
#  ('hd', ''),
#  ('4gb', ''),
#  ('vga', ''),
#  ('5cm', ''),
#  ('i7', ''),
#  ('lp', ''),
#  ('ghz', ''),
#  ('5g', ''),
#  ('512gb', ''),
#  ('mah', ''),
#  ('gr', ''),
#  ('ori', ''),
#  ('i3', ''),
#  ('hdd', ''),
#  ('1tb', ''),
#  ('ddr3', ''),
#  ('2x', ''),
#  ('4g', ''),
#  ('pb', ''),
#  ('lcd', ''),
#  ('5mm', ''),
#  ('mg', ''),
#  ('1kg', ''),
#  ('ddr4', ''),
#  ('30fps', ''),
#  ('64gb', ''),
#  ('70cm', ''),
#  ('ips', ''),
#  ('hdmi', ''),
#  ('nfc', ''),
#  ('rgb', ''),
#  ('100cm', ''),
#  ('ac', ''),
#  ('50cm', ''),
#  ('uv', ''),
#  ('3pcs', ''),
#  ('500gb', ''),
#  ('1080p', ''),
#  ('60cm', ''),
#  ('120hz', ''),
#  ('2cm', ''),
#  ('x1', ''),
#  ('ppi', ''),
#  ('km', ''),
#  ('kcal', ''),
#  ('sbc', ''),
#  ('mhz', ''),
#  ('aac', ''),
#  ('oled', ''),
#  ('sni', ''),
#  ('lbs', ''),
#  ('dpi', ''),
#  ('sku', ''),
#  ('enc', ''),
#  ('tb', ''),
#  ('srgb', ''),
#  ('hdr', ''),
#  ('gsm', ''),
#  ('lb', ''),
#  ('amoled', ''),
#  ('anc', ''),
#  ('iu', ''),
#  ('bpa', ''),
#  ('xxxl', ''),
#  ('g', ''),
#  ('esim', ''),
#  ('mcg', ''),
#  ('uht', ''),
#  ('cal', ''),
#  ('ir', ''),
#  ('xs', ''),
#  ('tws', ''),
#  ('pa', ''),
#  ('ble', ''),
#  ('oem', ''),
#  ('typec', ''),
#  ('hires', ''),
#  ('fps', ''),
#  ('spf', ''),
#  ('khz', ''),
#  ('ph', ''),
#  ('jpg', ''),
#  ('ppm', ''),
#  ('psi', ''),
#  ('uva', ''),
#  ('lte', ''),
#  ('mb', ''),
#  ('oz', ''),
#  ('volte', ''),
#  ('kb', ''),
#  ('bt', ''),
#  ('qc', ''),
#  ('hz', ''),
#  ('usbc', ''),
#  ('xxxs', ''),
#  ('uvb', ''),
#  ('exp', ''),
#  ('mfg', ''),
#  ('pd', ''),
#  ('ldac', '')]

# %%
# mapping hanya untuk entri yang punya ekspansi (aman untuk model):
acronym_dict = build_acronym_dict(df_all, keep_unmapped=False)

# Cek sebagian:
print({k: acronym_dict[k] for k in list(acronym_dict)[:20]})
# Out:
# {'ghz': 'gigahertz', 'km': 'kilometer', 'sbc': 'Subband Codec (codec audio)', '5mm': '5 milimeter', 'lbs': 'pounds', 'dpi': 'titik per inci', 'enc': 'Environmental Noise Cancelling', 's': 'Kecil', 'hdr': 'High Dynamic Range', 'gsm': 'Gram per meter persegi (kertas)', 'lb': 'pound', 'ac': 'arus bolak-balik', 'l': 'liter', 'amoled': 'Active Matrix Organic Light Emitting Diode', '2cm': '2 centimeter', '1080p': 'resolusi 1080p', '4g': '4 gram', 'cod': 'Bayar di tempat', 'bb': 'berat badan', 'bpom': 'Badan Pengawas Obat dan Makanan'}

# %%
# Simpan ke JSON:
with open("data/acronym_dict.json", "w", encoding="utf-8") as f:
    json.dump(acronym_dict, f, ensure_ascii=False, indent=2)

# %% [markdown]
# ## **Detect Rating Patterns**

# %%
# gabungan keyword rating yang mungkin
pattern_all = re.compile(r"(bintang|rating|rate|⭐|★|🌟|\d+/\d+)", re.IGNORECASE)

DATA_SOURCES = [
    {"name": "reviews_only", "path": "data/reviews_only.csv", "text_cols": ["review"]},
    {"name": "tokopedia_500", "path": "data/tokopedia_500.csv",
     "text_cols": ["product_name", "description", "category", "keyword"]},
]

def load_texts(df: pd.DataFrame, cols: list[str]) -> pd.Series:
    cols = [c for c in cols if c in df.columns]
    if not cols:
        return pd.Series(dtype=str)
    return df[cols].astype(str).fillna("").agg(" ".join, axis=1)

def get_snippets(text, regex, window=4):
    snippets = []
    for m in regex.finditer(text):
        # potong teks di sekitar match
        words = text.split()
        # cari index kata yang mengandung match
        for idx, w in enumerate(words):
            if m.group(0).lower() in w.lower():
                start = max(0, idx - window)
                end = min(len(words), idx + window + 1)
                snippet = " ".join(words[start:end])
                snippets.append(snippet)
                break
    return snippets

for src in DATA_SOURCES:
    path, name, cols = src["path"], src["name"], src["text_cols"]
    if not os.path.exists(path):
        print(f"⚠️ file tidak ditemukan: {path}")
        continue

    df = pd.read_csv(path)
    texts = load_texts(df, cols)

    print(f"\n=== Source: {name} ===")
    count = 0
    for t in texts:
        snippets = get_snippets(t, pattern_all, window=4)
        if snippets:
            for s in snippets[:2]:  # tampilkan max 2 snippet per baris biar ringkas
                print("→", s)
                count += 1
        if count >= 40:  # batas contoh total biar ga kepanjangan
            break
    print(f"(ditampilkan {count} snippet contoh)")
# Out:
# === Source: reviews_only ===
# → ProductReview(feedback_id=1269906046, variant_name='hitam', message='', rating=5.0, review_age='6 bulan lalu', user_full_name='E***o',
# → ProductReview(feedback_id=1649919524, variant_name='Agate Green', message='', rating=5.0, review_age='5 hari lalu', user_full_name='dony',
# → terbaru', response_created_text='5 hari lalu', images=['https://images.tokopedia.net/img/cache/600/aphluv/1997/1/1/6660d6c5ab0a418ea4e72e60c8c5bf9b~'], videos=[], likes=0)
# → harga kaki lima kualitas bintang 5... mudah2 awet ...
# → aftersell nya keren poll! bintang 1000++ beli disini ada
# → series tapi bahan yang berateful lebih tipis daripada yanga
# → produk: Sangat memuaskan 👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍 🌟🌟🌟🌟🌟
# → produk: Sangat memuaskan 👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍 🌟🌟🌟🌟🌟
# → abu - 4XL-5XL=38(90-102kg)', message='', rating=5.0, review_age='3 minggu lalu', user_full_name='S***w',
# → Sengaja ngasih bintang 5 supaya bisa di
# → Padhaal bintang nya bgus tapi bahan
# → bahan nya nyaman banget bestt⭐⭐⭐⭐⭐
# → bahan nya nyaman banget bestt⭐⭐⭐⭐⭐
# → ProductReview(feedback_id=1556262104, variant_name='Black', message='', rating=5.0, review_age='2 bulan lalu', user_full_name='V***c',
# → user_full_name='V***c', user_url='', response_message='', response_created_text='', images=['https://images.tokopedia.net/img/cache/600/aphluv/1997/1/1/5e1002fd3be342e080b8b311c986567f'], videos=[], likes=0)
# → buat tokonya pokonya amanah..biar bintang yang berbicara
# → ProductReview(feedback_id=907477825, variant_name='', message='', rating=1.0, review_age='Lebih dari 1 tahun
# → ProductReview(feedback_id=907477825, variant_name='', message='', rating=1.0, review_age='Lebih dari 1 tahun
# → ProductReview(feedback_id=1624958823, variant_name='Biru', message='', rating=5.0, review_age='3 minggu lalu', user_full_name='E***w',
# → user_full_name='E***w', user_url='', response_message='', response_created_text='', images=['https://images.tokopedia.net/img/cache/600/aphluv/1997/1/1/80492457ab6b430f82ed03b5ae219fd9'], videos=[], likes=0)
# → konsul juga baik, so bintang 5 ☺ Semoga cocok
# → Lelap 3 Strip', message='', rating=4.0, review_age='Lebih dari 1 tahun
# → barang diterima kualitas bintang 5 🌟 seperti biasa
# → diterima kualitas bintang 5 🌟 seperti biasa 👍 recommended
# → 🤝🙏 Berefek entar ➕ ⭐
# → bagus banget.. aku kasih bintang 5 buat respon dan
# → nih min. aku ksih bintang 5 buat pelayanan sma
# → sopan deh. nih 5 bintang buat servis sama kwalitas
# → ProductReview(feedback_id=647096685, variant_name='', message='', rating=5.0, review_age='Lebih dari 1 tahun
# → dari 1 tahun lalu', images=['https://images.tokopedia.net/img/cache/600/bjFkPX/2022/4/13/02ed7f13-39d6-4060-add1-5ee1a4ff4767.jpg'], videos=[], likes=1)
# → Tapi maaf saya kasih bintang 4 yaa~ Karena pesannya
# → and the model is accurate aswel, thank you 🙏🏼
# → lah ama action figure 1/12 punya saya
# → itu aja sisanya OKEEEW 90/100 GES
# → ProductReview(feedback_id=1630540355, variant_name='Sweet Cheezy', message='', rating=5.0, review_age='2 minggu lalu', user_full_name='I***p',
# → user_full_name='I***p', user_url='', response_message='', response_created_text='', images=['https://images.tokopedia.net/img/cache/600/aphluv/1997/1/1/de8231ceb9134b30a1f269474abf0968'], videos=[], likes=0)
# → tangan kita,, aku kasih bintang 4 karna ketolong sama
# → too much tapi oke!! ⭐⭐⭐
# → too much tapi oke!! ⭐⭐⭐
# → gtu kataku, sukses trs yaaa⭐⭐⭐⭐⭐
# → gtu kataku, sukses trs yaaa⭐⭐⭐⭐⭐
# (ditampilkan 41 snippet contoh)
#
# === Source: tokopedia_500 ===
# → tombol di bawah air). ★Pengiriman: Pesanan akan dikirim dalam
# → (Optical) Input AC 180-240V~ 50/60Hz Konsumsi Daya 115 Watt
# → 75 BAR G : 1/4 INCH UB : 18...30
# → Performa Tinggi Parameter Layar: 22/24/27 Inci IPS Bezel-less (Pilihan
# → Daya Adaptif: Input 100-220V～3A 50/60Hz, Output 19VDC-5A Parameter WiFi:
# → Ukuran 6.7 inci Refresh Rate 60 Hz Resolusi 1290
# → HDR (photo/panorama); Video: Hingga 4K@24/25/30/60fps, HDR, Dolby Vision HDR
# → Elektronik Commitment from shop: ★All products support cash on
# → Elektronik Commitment from shop: ★All products support cash on
# → Ukuran 6.3 inci Refresh Rate 120 Hz Resolusi 1206
# → HDR (photo/panorama); Video: Hingga 4K@24/25/30/60fps, Cinematic mode (4K@30fps), gyro-EIS;
# → : 220V Frekuensi : 50/50 Hz Daya : 300w
# → x 1,080) - Motion Rate : 50 - PQI
# → 3. Bahan Berkualitas Tinggi: 1/20 skala 11CH, bisa sebagai
# → cable:220-230 power cord Frekuensi: 50/60Hz Catatan : Setiap Hari
# → Lebih Efisien Memiliki conversion rate 55–60% sehingga mampu mengubah
# → Lebih Efisien Memiliki conversion rate 55–60% sehingga mampu mengubah
# → Infinix Hot 60i 8/256GB - Up to 16GB
# → Infinix Hot 60i 8/256GB - Up to 16GB
# → (3,840 x 2,160) Refresh Rate 50Hz HDMI 3 LED
# → (3,840 x 2,160) Refresh Rate 50Hz HDMI 3 LED
# → Bluetooth/USB/TF/AUX BT : 5.0 Rated power : 5W*2 Dimensi
# → NPB: 2-163-116-241230-5 No. SNI: 922/LSPr-058-IDN/003/04/2024 Metode Pengujian: SNI 7859:2013
# → Pabrik untuk Elemen Pemanas ⭐Open Order 24 Jam ⭐Order
# → Pabrik untuk Elemen Pemanas ⭐Open Order 24 Jam ⭐Order
# → Happy shopping Jangan Lupa Bintang 5 Kipas Angin Listrik
# → dan menyenangkan bagi pengguna. ⭐Tidak perlu menggerakkan badan, kontrol
# → dan menyenangkan bagi pengguna. ⭐Tidak perlu menggerakkan badan, kontrol
# → Listrik : 220-240V / 50/60 Hz Blender BL2 adalah
# → : 220V -Frekuensi : 50/60 Hz -Daya Motor Pencuci
# → Cair & Gas (Inch) ⌀1/4 ⌀3/8 Dimensi Ou. (p
# → & Gas (Inch) ⌀1/4 ⌀3/8 Dimensi Ou. (p x
# → pesanan Anda dan pujian bintang lima 🔥🔥Pengingat: Pelanggan yang
# → melayani Anda. 🧑🎤Parameter produk ⭐ 【Model】: S20 ⭐ 【Kualitas
# → Daya : 700 Watt Rated Voltage : 220-240V Rated
# → Daya : 700 Watt Rated Voltage : 220-240V Rated
# → Infinix Hot 40i 8/256 50MP 5000mah 18W Garansi
# → a positive feedback (5 stars⭐⭐⭐⭐⭐) , if you are
# → a positive feedback (5 stars⭐⭐⭐⭐⭐) , if you are
# → WPower SupplyAC 100-240V ~ 50/60Hz ; DC 13.5 V
# (ditampilkan 40 snippet contoh)

# %%
PATTERNS = {
    # --- ANGKA /5 -----------------------------------------------------------
    "frac_out_of_5": r"\b([1-5](?:[.,]5)?)\s*/\s*5\b",
    # contoh: "4.5/5 mantap", "5/5 recommended", "4,5/5 untuk kualitas"

    # --- “BINTANG” + ANGKA --------------------------------------------------
    "bintang_number": r"\bbintang\s*([1-5](?:[.,]5)?)\b",
    # contoh: "bintang 5, puas!", "bintang 4,5 cukup oke"

    "number_bintang": r"\b([1-5])\s*bintang\b",
    # contoh: "5 bintang buat seller ini", "2 bintang karena packing kurang"

    "word_number_bintang": r"\b(satu|dua|tiga|empat|lima)\s*bintang\b",
    # contoh: "tiga bintang, sesuai harga", "lima bintang pokoknya"

    # variasi “bintangnya 5”
    "bintangnya_number": r"\bbintang(?:nya|ny| nya)\s*([1-5])\b",
    # contoh: "bintangnya 5", "bintangnya 4 karena telat kirim"

    # user memberi/“kasih” bintang
    "kasih_bintang": r"\b(kasih|beri|dapat|ngasih)\s*([1-5])\s*bintang\b",
    # contoh: "kasih 5 bintang", "dapat 3 bintang dari saya"
    
    # khusus "bintang 1000++" / angka besar → langsung map ke 5
    "bintang_many": r"\bbintang\s*\d{3,}(?:\++)?(?=\s|$|[^\w])",
    # contoh: "bintang 1000++", "bintang 2000+"

    # --- SETENGAH BINTANG ---------------------------------------------------
    "fraction_half": r"\b([1-5])(?:\s?½|(?:\s?1\/2)|[.,]5)\s*/\s*5\b",
    # contoh: "4½/5 layak beli", "4 1/2 / 5", "4,5/5"

    "bintang_half_after": r"\bbintang\s*([1-5])(?:\s?½|(?:\s?1\/2)|[.,]5)\b",
    # contoh: "bintang 4½", "bintang 3,5 untuk kualitas"

    "bintang_half_before": r"\b([1-5])(?:\s?½|(?:\s?1\/2)|[.,]5)\s*bintang\b",
    # contoh: "4,5 bintang", "3½ bintang cukup"

    # --- SKALA LAIN (opsional: remap ke 1–5) --------------------------------
    "out_of_ten": r"\b([0-9]{1,2}(?:[.,]5)?)\s*/\s*10\b",
    # contoh: "9/10 worth it", "8,5/10 untuk fitur"

    # --- “RATING/RATE/NILAI/SKOR” ------------------------------------------
    "rating_colon": r"\b(rating|rate|nilai|skor|score|grade)\s*[:\-]?\s*([1-5](?:[.,]5)?)\b",
    # contoh: "rating: 5", "nilai 4,5", "skor-4"

    # --- “STARS” DALAM BAHASA INGGRIS/INDO ---------------------------------
    "en_stars_word": r"\b([1-5])\s*stars?\b",
    # contoh: "4 stars overall", "5 star quality"

    "id_stars_word": r"\b(satu|dua|tiga|empat|lima)\s*star\b",
    # contoh: "tiga star lumayan", "lima star terbaik"

    # --- EMOJI / SIMBOL BINTANG --------------------------------------------
    "stars_repeated": r"(?:⭐(?:\uFE0F)?|★|🌟|✩|✮|✯){2,10}",
    # contoh: "★★★★★", "⭐⭐⭐⭐⭐", "🌟🌟🌟", "⭐️⭐️⭐️⭐️⭐️"  (⭐️ = '⭐' + FE0F)

    "star_multiplication": r"(?:⭐(?:\uFE0F)?|★)\s*[xX×]\s*([1-5])",
    # contoh: "⭐ x5", "★×4 bagus", "⭐x3 lumayan"

    # --- VARIASI TANDA ------------------------------------------------------
    "paren_or_bracket_5_5": r"[\(\[]\s*([1-5](?:[.,]5)?)\s*/\s*5\s*[\)\]]",
    # contoh: "(5/5) recommended", "[4,5/5] puas"

    # --- GAYA “OF/DR” -------------------------------------------------------
    "number_of_number": r"\b([1-5])\s*(?:of|dr)\s*5\b",
    # contoh: "4 of 5 for design", "3 dr 5 lah"
    
}

# %%
import re
s = "aftersell nya keren poll! bintang 1000++ beli disini ada"
rx = re.compile(r"\bbintang\s*\d{3,}(?:\+{1,2})?(?=\s|$|[^\w])", re.IGNORECASE)
print(bool(rx.search(s)))  # True kalau fix-nya bekerja
# Out:
# True

# %%
FLAGS = re.IGNORECASE | re.MULTILINE
COMPILED = {k: re.compile(v, FLAGS) for k, v in PATTERNS.items()}

# %%
# --- 2) sumber data & kolom teks yang dipakai ---
DATA_SOURCES = [
    {
        "name": "reviews_only",
        "path": "data/reviews_only.csv",
        "text_cols": ["review"],  # hanya kolom ini yang ada
    },
    {
        "name": "tokopedia_500",
        "path": "data/tokopedia_500.csv",
        # pilih kolom teks yang relevan (hindari kolom numerik)
        "text_cols": ["product_name", "description", "category", "keyword"],
    },
]

# %%
# --- util: gabung beberapa kolom teks jadi satu string per baris ---
def load_texts(df: pd.DataFrame, cols: list[str]) -> pd.Series:
    cols = [c for c in cols if c in df.columns]
    if not cols:
        return pd.Series(dtype=str)
    s = df[cols].astype(str).fillna("").agg(" ".join, axis=1)
    return s[s.str.strip() != ""]

def probe_series(series: pd.Series, compiled: dict, n_examples: int = 5):
    counts = defaultdict(int)
    examples = defaultdict(list)
    for t in series.astype(str).fillna(""):
        for name, rx in compiled.items():
            ms = list(rx.finditer(t))
            if not ms:
                continue
            counts[name] += len(ms)
            if len(examples[name]) < n_examples:
                m = ms[0]
                start, end = max(0, m.start()-25), min(len(t), m.end()+25)
                examples[name].append(t[start:end])
    rows = []
    for name in compiled.keys():
        rows.append({
            "pattern": name,
            "count": int(counts.get(name, 0)),
            "examples": examples.get(name, []),
        })
    return pd.DataFrame(rows).sort_values("count", ascending=False).reset_index(drop=True)

# %%
# --- 3) run: per-source & total ---
per_source = []
tot_counts = defaultdict(int)
tot_examples = defaultdict(list)

for src in DATA_SOURCES:
    path, name = src["path"], src["name"]
    if not os.path.exists(path):
        print(f"⚠️ file tidak ditemukan: {path}")
        continue
    df = pd.read_csv(path)
    texts = load_texts(df, src["text_cols"])
    if texts.empty:
        print(f"⚠️ {name}: tidak ada teks yang bisa dipakai.")
        continue

    df_probe = probe_series(texts, COMPILED, n_examples=5)
    df_probe.insert(0, "source", name)
    per_source.append(df_probe)

    for _, row in df_probe.iterrows():
        p = row["pattern"]
        tot_counts[p] += int(row["count"])
        for ex in row["examples"]:
            if len(tot_examples[p]) < 5:
                tot_examples[p].append(ex)
                
# simpan per-source
if per_source:
    df_all = pd.concat(per_source, ignore_index=True)
    df_all.to_csv("rating_probe_per_source.csv", index=False)
    print("✅ disimpan: rating_probe_per_source.csv")
else:
    print("⚠️ tidak ada sumber yang valid.")
# Out:
# ✅ disimpan: rating_probe_per_source.csv

# %%
# simpan total
summary = []
for name in PATTERNS.keys():
    summary.append({
        "pattern": name,
        "total_count": tot_counts.get(name, 0),
        "examples": tot_examples.get(name, []),
    })
df_total = pd.DataFrame(summary).sort_values("total_count", ascending=False)
# df_total.to_csv("rating_probe_total.csv", index=False)
# df_total.to_json("rating_probe_total.json", orient="records", force_ascii=False, indent=2)
# print("✅ disimpan: rating_probe_total.(csv|json)")

print("\nTop 20 total pattern:")
print(df_total[["pattern","total_count"]].head(20))
# Out:
# Top 20 total pattern:
#                  pattern  total_count
# 1         bintang_number           98
# 14        stars_repeated           23
# 0          frac_out_of_5           18
# 2         number_bintang           16
# 11          rating_colon            8
# 10            out_of_ten            7
# 12         en_stars_word            1
# 3    word_number_bintang            1
# 6           bintang_many            1
# 16  paren_or_bracket_5_5            0
# 15   star_multiplication            0
# 13         id_stars_word            0
# 9    bintang_half_before            0
# 8     bintang_half_after            0
# 7          fraction_half            0
# 5          kasih_bintang            0
# 4      bintangnya_number            0
# 17      number_of_number            0

# %% [markdown]
# ### Making the dictionary

# %%
EXAMPLES = {
    "frac_out_of_5": "4.5/5 mantap",
    "bintang_number": "bintang 4,5 cukup oke",
    "number_bintang": "5 bintang buat seller ini",
    "word_number_bintang": "tiga bintang, sesuai harga",
    "bintangnya_number": "bintangnya 4 karena telat kirim",
    "kasih_bintang": "kasih 5 bintang",
    "bintang_many": "bintang 1000++",
    "fraction_half": "4½/5 layak beli",
    "bintang_half_after": "bintang 3,5 untuk kualitas",
    "bintang_half_before": "4,5 bintang",
    "out_of_ten": "9/10 worth it",
    "rating_colon": "rating: 5",
    "en_stars_word": "4 stars overall",
    "id_stars_word": "tiga star lumayan",
    "stars_repeated": "⭐⭐⭐⭐⭐",
    "star_multiplication": "⭐ x5",
    "paren_or_bracket_5_5": "(5/5) recommended",
    "number_of_number": "4 of 5 for design"
}

# %% [markdown]
# **simple rating_patterns dictiinary**

# %%
# ---------- 2) patterns.json (cuma regex + example) ----------
def build_patterns_json(patterns, examples):
    return [
        {"id": k, "pattern": v, "example": examples.get(k, "")}
        for k,v in patterns.items()
    ]

# %%
from pathlib import Path

patterns_json = build_patterns_json(PATTERNS, EXAMPLES)
Path("rating_patterns.json").write_text(json.dumps(patterns_json, ensure_ascii=False, indent=2), encoding="utf-8")
# Out:
# 2404

# %% [markdown]
# **advanced rating_rules dictionary**

# %%
# 2) GENERATOR
WORD2NUM = {"satu":1,"dua":2,"tiga":3,"empat":4,"lima":5}
PRIORITY_ORDER = [
    "frac_out_of_5", "paren_or_bracket_5_5",
    "bintang_many", "bintang_number", "number_bintang",
    "word_number_bintang", "bintangnya_number", "kasih_bintang",
    "bintang_half_after", "bintang_half_before", "fraction_half",
    "rating_colon",
    "en_stars_word", "id_stars_word",
    "stars_repeated", "star_multiplication",
    "number_of_number",
]
PRIORITY_BASE = 100

# %%
def build_patterns_json():
    """Versi ringkas: id, pattern, example."""
    items = []
    for k, v in PATTERNS.items():
        items.append({"id": k, "pattern": v, "example": EXAMPLES.get(k, "")})
    return items

def infer_rule(key: str, pattern: str) -> dict:
    """Bangun 1 rule lengkap untuk rating_rules.json dari PATTERNS."""
    rule = {"id": key, "pattern": pattern, "example": EXAMPLES.get(key, "")}

    # Tipe khusus
    if key == "stars_repeated":
        rule.update({
            "type": "count_emoji",
            "emojis": ["⭐","★","🌟","✩","✮","✯"],
            "min_count": 2, "max_count": 5
        })
    elif key == "bintang_many":
        rule.update({"type": "assign", "value": 5.0})
    elif key in ("word_number_bintang", "id_stars_word"):
        rule.update({
            "type": "assign",
            "mapping": WORD2NUM,
            "value_from_group": 1
        })
    elif key in ("bintang_half_after", "bintang_half_before"):
        rule.update({
            "type": "extract",
            "value_group": 1,
            "add": 0.5,
            "postprocess": {"replace": {",":"."}},
            "clamp": [1.0, 5.0]
        })
    elif key == "star_multiplication":
        rule.update({
            "type": "extract",
            "value_group": 1,
            "clamp": [1.0, 5.0]
        })
    else:
        # default: extract angka dari group pertama kalau ada,
        # lalu normalisasi dan clamp
        if re.search(r"\((?!\?:).*?\)", pattern):
            rule.update({
                "type": "extract",
                "value_group": 1,
                "postprocess": {"replace": {",":"."}},
                "clamp": [1.0, 5.0]
            })
        else:
            # fallback aman: treat as assign 5 (jarang kena di set ini)
            rule.update({"type": "assign", "value": 5.0})

    # priority
    if key in PRIORITY_ORDER:
        priority = PRIORITY_BASE - PRIORITY_ORDER.index(key)*2
    else:
        priority = 50
    rule["priority"] = priority

    return rule

# %%
def build_rating_rules_json(include_out_of_ten: bool = False):
    rules = []
    for k, v in PATTERNS.items():
        if not include_out_of_ten and k == "out_of_ten":
            continue  # exclude by default
        rules.append(infer_rule(k, v))
    rules = sorted(rules, key=lambda r: -r["priority"])
    return {
        "schema_version": "1.0",
        "defaults": {
            "flags": ["IGNORECASE", "MULTILINE"],
            "min_rating": 1.0,
            "max_rating": 5.0
        },
        "rules": rules,
        "blacklist": [
            {
                "id": "star_bullet_single",
                "pattern": r"^[\s]*[★⭐]",
                "reason": "Bullet list (satu bintang di awal baris), bukan rating."
            }
        ]
    }

# %%
def save_all(out_dir: str = "."):
    out = Path(out_dir)
    out.mkdir(parents=True, exist_ok=True)

    rating_rules_json = build_rating_rules_json(include_out_of_ten=False)
    (out / "rating_rules.json").write_text(
        json.dumps(rating_rules_json, ensure_ascii=False, indent=2), encoding="utf-8"
    )
    print("✅ created:", out / "rating_rules.json")

# %%
if __name__ == "__main__":
    save_all(".")
# Out:
# ✅ created: rating_rules.json
